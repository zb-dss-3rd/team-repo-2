# %%
import os
import json
import glob
import random
import collections

import numpy as np
import pandas as pd
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers



TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]
WHITE_THRESHOLD = 10 # out of 255
EXCLUDE = [109, 123, 709]

base_path = 'D:\zerobase\Brain_tumor'

train_df = pd.read_csv(base_path + "/train_df.csv")
test_df = pd.read_csv(base_path + '/test_df.csv')
train_df = train_df[~train_df.BraTS21ID.isin(EXCLUDE)]
def load_dicom(path, size = 224):
    ''' 
    Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, then rescales to 0 and 255
    
    Note super sure if this kind of scaling is appropriate, but everyone seems to do it. 
    '''
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if np.max(data) != 0:
        data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return cv2.resize(data, (size, size))

def get_all_image_paths(brats21id, image_type, folder='train'): 
    '''
    Returns an arry of all the images of a particular type for a particular patient ID
    '''
    assert(image_type in TYPES)
    
    patient_path = os.path.join(
        base_path + "/%s/" % folder, 
        str(brats21id).zfill(5),
    )

    paths = sorted(
        glob.glob(os.path.join(patient_path, image_type, "*")), 
        key=lambda x: int(x[:-4].split("-")[-1]),
    )
    
    num_images = len(paths)
    
    start = int(num_images * 0.25)
    end = int(num_images * 0.75)

    interval = 3
    
    if num_images < 10: 
        interval = 1
    
    return np.array(paths[start:end:interval])

def get_all_images(brats21id, image_type, folder='train', size=225):
    return [load_dicom(path, size) for path in get_all_image_paths(brats21id, image_type, folder)]
IMAGE_SIZE = 128

def get_all_data_for_train(image_type):
    global train_df
    
    X = []
    y = []
    train_ids = []

    for i in tqdm(train_df.index):
        x = train_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        label = x['MGMT_value']

        X += images
        y += [label] * len(images)
        train_ids += [int(x['BraTS21ID'])] * len(images)
        assert(len(X) == len(y))
    return np.array(X), np.array(y), np.array(train_ids)

def get_all_data_for_test(image_type):
    global train_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

def get_all_data_for_val(image_type):
    global test_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

X, y, trainidt = get_all_data_for_train('T1wCE')
X_test, testidt = get_all_data_for_test('T1wCE')
X.shape, y.shape, trainidt.shape
# Out:
#   0%|          | 0/466 [00:00<?, ?it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]
# ((12832, 128, 128), (12832,), (12832,))

# %%
X_train, X_valid, y_train, y_valid, trainidt_train, trainidt_valid = train_test_split(X, y, trainidt, test_size=0.2, random_state=40)


split = int(X.shape[0] * 0.8)

# X_train = X[:split]
# X_valid = X[split:]

# y_train = y[:split]
# y_valid = y[split:]

# trainidt_train = trainidt[:split]
# trainidt_valid = trainidt[split:]

X_train = tf.expand_dims(X_train, axis=-1)
X_valid = tf.expand_dims(X_valid, axis=-1)

y_train = to_categorical(y_train)
y_valid = to_categorical(y_valid)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, trainidt_train.shape, trainidt_valid.shape
# Out:
# (TensorShape([10265, 128, 128, 1]),
#  (10265, 2),
#  TensorShape([2567, 128, 128, 1]),
#  (2567, 2),
#  (10265,),
#  (2567,))

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
np.random.seed(0)
random.seed(12)
tf.random.set_seed(12)

inpt = keras.Input(shape=(128, 128, 1))

h = keras.layers.experimental.preprocessing.Rescaling(1./255)(inpt)
# h = data_augmentation(h)

# convolutional layer!
h = keras.layers.Conv2D(32, kernel_size=(3, 3),strides=(1,1), activation="relu", name="Conv_1", padding="valid")(h) 
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
h = keras.layers.Conv2D(64, kernel_size=(3, 3),strides=(1,1), activation="relu", name="Conv_2", padding="same")(h) 
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
# pooling layer
h = keras.layers.MaxPool2D(pool_size=(2,2))(h) 
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
# convolutional layer!
h = keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu", name="Conv_3",padding ="same")(h)
# h = tf.keras.layers.BatchNormalization(axis=-1)(h)
# pooling layer
# h = keras.layers.MaxPool2D(pool_size=(1,1))(h)
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
h = keras.layers.Conv2D(128, kernel_size=(3, 3), activation="relu", name="Conv_4",padding ="valid")(h)
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
h = keras.layers.Conv2D(128, kernel_size=(3, 3), activation="relu", name="Conv_5",padding ="same")(h)
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
h = keras.layers.MaxPool2D(pool_size=(2,2))(h)
h = tf.keras.layers.BatchNormalization(axis=-1)(h)
h = keras.layers.Dropout(0.3)(h)   

h = keras.layers.Flatten()(h) 
# h = global_average_layer(h)
h = keras.layers.Dense(128, activation='relu')(h)   

output = keras.layers.Dense(2, activation="softmax")(h)

model = keras.Model(inpt, output)

from tensorflow.keras.optimizers import SGD
# opt = SGD(lr=0.1)

checkpoint_filepath = 'best_model.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
filepath=checkpoint_filepath,
save_weights_only=False,
monitor='val_auc',
mode='max',
save_best_only=True,
save_freq='epoch')

model.compile(loss='categorical_crossentropy',
             optimizer=tf.keras.optimizers.SGD(learning_rate =0.0001),
             metrics=[tf.keras.metrics.AUC()])

history = model.fit(x=X_train, y = y_train, epochs=50, callbacks=[model_checkpoint_callback], validation_data= (X_valid, y_valid))
# Out:
# Epoch 1/50
# 321/321 [==============================] - 49s 107ms/step - loss: 0.7614 - auc: 0.5847 - val_loss: 0.6931 - val_auc: 0.5739
# Epoch 2/50
# 321/321 [==============================] - 32s 100ms/step - loss: 0.6706 - auc: 0.6504 - val_loss: 0.6758 - val_auc: 0.6165
# Epoch 3/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.6400 - auc: 0.6874 - val_loss: 0.6544 - val_auc: 0.6593
# Epoch 4/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.6112 - auc: 0.7218 - val_loss: 0.6348 - val_auc: 0.6902
# Epoch 5/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.5942 - auc: 0.7432 - val_loss: 0.6247 - val_auc: 0.7052
# Epoch 6/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.5712 - auc: 0.7700 - val_loss: 0.6176 - val_auc: 0.7150
# Epoch 7/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.5581 - auc: 0.7846 - val_loss: 0.5998 - val_auc: 0.7399
# Epoch 8/50
# 321/321 [==============================] - 32s 101ms/step - loss: 0.5411 - auc: 0.8005 - val_loss: 0.5936 - val_auc: 0.7467
# Epoch 9/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.5192 - auc: 0.8203 - val_loss: 0.5823 - val_auc: 0.7616
# Epoch 10/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.4943 - auc: 0.8431 - val_loss: 0.5734 - val_auc: 0.7691
# Epoch 11/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.4759 - auc: 0.8579 - val_loss: 0.5612 - val_auc: 0.7810
# Epoch 12/50
# 321/321 [==============================] - 32s 100ms/step - loss: 0.4637 - auc: 0.8661 - val_loss: 0.5477 - val_auc: 0.7983
# Epoch 13/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.4475 - auc: 0.8779 - val_loss: 0.5398 - val_auc: 0.8037
# Epoch 14/50
# 321/321 [==============================] - 32s 99ms/step - loss: 0.4297 - auc: 0.8902 - val_loss: 0.5238 - val_auc: 0.8182
# Epoch 15/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.4083 - auc: 0.9044 - val_loss: 0.5263 - val_auc: 0.8144
# Epoch 16/50
# 321/321 [==============================] - 32s 100ms/step - loss: 0.3978 - auc: 0.9100 - val_loss: 0.5115 - val_auc: 0.8293
# Epoch 17/50
# 321/321 [==============================] - 32s 98ms/step - loss: 0.3838 - auc: 0.9173 - val_loss: 0.5099 - val_auc: 0.8281
# Epoch 18/50
# 321/321 [==============================] - 32s 98ms/step - loss: 0.3626 - auc: 0.9296 - val_loss: 0.5072 - val_auc: 0.8331
# Epoch 19/50
# 321/321 [==============================] - 33s 101ms/step - loss: 0.3487 - auc: 0.9371 - val_loss: 0.4973 - val_auc: 0.8371
# Epoch 20/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.3372 - auc: 0.9415 - val_loss: 0.4900 - val_auc: 0.8468
# Epoch 21/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.3205 - auc: 0.9496 - val_loss: 0.4854 - val_auc: 0.8501
# Epoch 22/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.3132 - auc: 0.9515 - val_loss: 0.4687 - val_auc: 0.8599
# Epoch 23/50
# 321/321 [==============================] - 31s 98ms/step - loss: 0.3009 - auc: 0.9571 - val_loss: 0.4627 - val_auc: 0.8638
# Epoch 24/50
# 321/321 [==============================] - 31s 97ms/step - loss: 0.2901 - auc: 0.9601 - val_loss: 0.4717 - val_auc: 0.8588
# Epoch 25/50
# 321/321 [==============================] - 32s 99ms/step - loss: 0.2731 - auc: 0.9676 - val_loss: 0.4581 - val_auc: 0.8663
# Epoch 26/50
# 321/321 [==============================] - 35s 108ms/step - loss: 0.2689 - auc: 0.9680 - val_loss: 0.4512 - val_auc: 0.8703
# Epoch 27/50
# 321/321 [==============================] - 35s 110ms/step - loss: 0.2550 - auc: 0.9729 - val_loss: 0.4405 - val_auc: 0.8778
# Epoch 28/50
# 321/321 [==============================] - 36s 111ms/step - loss: 0.2466 - auc: 0.9749 - val_loss: 0.4554 - val_auc: 0.8693
# Epoch 29/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.2421 - auc: 0.9758 - val_loss: 0.4368 - val_auc: 0.8796
# Epoch 30/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.2294 - auc: 0.9797 - val_loss: 0.4552 - val_auc: 0.8699
# Epoch 31/50
# 321/321 [==============================] - 35s 109ms/step - loss: 0.2168 - auc: 0.9827 - val_loss: 0.4367 - val_auc: 0.8797
# Epoch 32/50
# 321/321 [==============================] - 35s 108ms/step - loss: 0.2125 - auc: 0.9837 - val_loss: 0.4288 - val_auc: 0.8845
# Epoch 33/50
# 321/321 [==============================] - 35s 109ms/step - loss: 0.2020 - auc: 0.9858 - val_loss: 0.4310 - val_auc: 0.8841
# Epoch 34/50
# 321/321 [==============================] - 34s 105ms/step - loss: 0.1967 - auc: 0.9874 - val_loss: 0.4346 - val_auc: 0.8810
# Epoch 35/50
# 321/321 [==============================] - 34s 105ms/step - loss: 0.1888 - auc: 0.9890 - val_loss: 0.4290 - val_auc: 0.8857
# Epoch 36/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.1819 - auc: 0.9898 - val_loss: 0.4084 - val_auc: 0.8963
# Epoch 37/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1731 - auc: 0.9912 - val_loss: 0.4163 - val_auc: 0.8915
# Epoch 38/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1705 - auc: 0.9918 - val_loss: 0.4200 - val_auc: 0.8900
# Epoch 39/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1633 - auc: 0.9929 - val_loss: 0.4099 - val_auc: 0.8952
# Epoch 40/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.1541 - auc: 0.9943 - val_loss: 0.4092 - val_auc: 0.8956
# Epoch 41/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1496 - auc: 0.9946 - val_loss: 0.4093 - val_auc: 0.8956
# Epoch 42/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1477 - auc: 0.9947 - val_loss: 0.4077 - val_auc: 0.8970
# Epoch 43/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.1436 - auc: 0.9951 - val_loss: 0.3994 - val_auc: 0.9009
# Epoch 44/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1349 - auc: 0.9960 - val_loss: 0.3928 - val_auc: 0.9043
# Epoch 45/50
# 321/321 [==============================] - 34s 105ms/step - loss: 0.1345 - auc: 0.9958 - val_loss: 0.4018 - val_auc: 0.9004
# Epoch 46/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.1294 - auc: 0.9961 - val_loss: 0.4168 - val_auc: 0.8932
# Epoch 47/50
# 321/321 [==============================] - 35s 108ms/step - loss: 0.1269 - auc: 0.9966 - val_loss: 0.3989 - val_auc: 0.9025
# Epoch 48/50
# 321/321 [==============================] - 34s 106ms/step - loss: 0.1199 - auc: 0.9973 - val_loss: 0.4015 - val_auc: 0.9012
# Epoch 49/50
# 321/321 [==============================] - 35s 109ms/step - loss: 0.1152 - auc: 0.9974 - val_loss: 0.3867 - val_auc: 0.9080
# Epoch 50/50
# 321/321 [==============================] - 34s 107ms/step - loss: 0.1134 - auc: 0.9979 - val_loss: 0.4059 - val_auc: 0.8991

# %%
def get_confusion_matrix(result3, threshold=0.5):

    confusion_matrix = [[0, 0], [0, 0]]

#     for i in range(len(result3)):
#         threshold = 1 if result3.loc[i, "MGMT_value_x"] > threshold else 0
#         confusion_matrix[result3.loc[i, "MGMT_value_y"]][threshold] += 1
        
    for idx, data in result3.iterrows():
        threshold = 1 if data.MGMT_value_x > threshold else 0
        
        print('data.MGMT_value_x : ',data.MGMT_value_x)
        print('threshold : ',threshold)
        print('data.MGMT_value_y : ',data.MGMT_value_y)
        
        confusion_matrix[int(data.MGMT_value_y)][threshold] += 1

    return confusion_matrix

def get_acc_recall(arr):
    acc = sum((arr[0][0], arr[1][1]))/sum((sum(arr[0]), sum(arr[1])))
    recall = arr[1][1] / sum(arr[1])
    print(f"Acc: {acc} \t Recall: {recall}")

# %%
def loss(y_true, y_pred):
    return - (1 - theta(y_true - margin) * theta(y_pred - margin)
                - theta(1 - margin - y_true) * theta(1 - margin - y_pred)
             ) * (y_true * K.log(y_pred + 1e-8) + (1 - y_true) * K.log(1 - y_pred + 1e-8))

import tensorflow as tf

margin = 0.6
theta = lambda t: (K.sign(t)+1.)/2.

def mish(inputs):
    x = tf.nn.softplus(inputs)
    x = tf.nn.tanh(x)
    x = tf.multiply(x, inputs)
    return x


X_val, validt = get_all_data_for_val('T1wCE')

model_path = [
 './best_model.h5',
]

pred_list = []
for path in model_path:
    model_best = tf.keras.models.load_model(filepath=path,custom_objects={"loss":loss,'leaky_relu': tf.nn.leaky_relu,'mish':mish})
    
#     sample = pd.read_csv(base_path + '/test_df.csv')
    y_pred = model_best.predict(X_val)
    #pred = np.argmax(y_pred, axis=1)
    pred_list.append(y_pred)


sample = pd.read_csv(base_path + '/test_df.csv')

y_pred = sum(pred_list)/len(pred_list)

pred = np.argmax(y_pred, axis=1)

result=pd.DataFrame(testidt)
result[1]=pred 

result.columns=['BraTS21ID','MGMT_value']
result2 = result.groupby('BraTS21ID',as_index=False).mean()
result2['BraTS21ID'] = sample['BraTS21ID']

result2.to_csv('submission_best_score_2dcnn.csv',index=False)
result2
# Out:
#   0%|          | 0/117 [00:00<?, ?it/s]
#      BraTS21ID  MGMT_value
# 0          107    0.409091
# 1          753    0.683333
# 2          303    0.650000
# 3          106    0.700000
# 4          171    0.863636
# ..         ...         ...
# 112        703    0.400000
# 113         21    0.187500
# 114        444    0.571429
# 115         95    0.468750
# 116        640    0.250000
#
# [117 rows x 2 columns]

# %%
result2['MGMT_value_y'] = test_df['MGMT_value']
result2.columns=[['BrsTS21ID','MGMT_value_x','MGMT_value_y']]
result2
# Out:
#     BrsTS21ID MGMT_value_x MGMT_value_y
# 0         107     0.409091            1
# 1         753     0.683333            0
# 2         303     0.650000            1
# 3         106     0.700000            1
# 4         171     0.863636            1
# ..        ...          ...          ...
# 112       703     0.400000            0
# 113        21     0.187500            0
# 114       444     0.571429            0
# 115        95     0.468750            0
# 116       640     0.250000            1
#
# [117 rows x 3 columns]

# %%
arr = get_confusion_matrix(result2)
print(arr)
get_acc_recall(arr)
# Out:
# data.MGMT_value_x :  0.4090909090909091
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6833333333333333
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.65
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8636363636363636
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.45454545454545453
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7358490566037735
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.45454545454545453
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.625
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.9090909090909091
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8620689655172413
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.6363636363636364
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.25
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.5
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.25
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.625
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.75
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.3333333333333333
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.38461538461538464
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.3125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.71875
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.53125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.03125
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.78125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.25
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.6875
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.75
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.125
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.78125
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.25
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.09375
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.46875
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.21875
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.28125
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.28125
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.4375
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.5625
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.28125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8125
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0625
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.4375
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.28125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8125
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.28125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.40625
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.03125
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.28125
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.1875
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.15625
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.3125
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.8125
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.65625
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.2
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.4444444444444444
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.4666666666666667
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6129032258064516
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.7777777777777778
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  1.0
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.3611111111111111
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.9655172413793104
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.4090909090909091
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6271186440677966
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6666666666666666
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.7837837837837838
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.7894736842105263
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7837837837837838
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.627906976744186
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8636363636363636
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8055555555555556
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6363636363636364
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.2903225806451613
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.4090909090909091
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.14285714285714285
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.9
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.6086956521739131
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.43478260869565216
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8695652173913043
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.71875
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.5
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.8135593220338984
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.9310344827586207
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.7058823529411765
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.71875
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.9491525423728814
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.71875
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.43333333333333335
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.5806451612903226
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.8461538461538461
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.6666666666666666
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.84375
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6521739130434783
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.75
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7796610169491526
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7647058823529411
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.6666666666666666
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.696969696969697
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.65625
# threshold :  0
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.7
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.4444444444444444
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.7419354838709677
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.9032258064516129
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.696969696969697
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.0
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.5
# threshold :  1
# data.MGMT_value_y :  1.0
# data.MGMT_value_x :  0.4
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.1875
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.5714285714285714
# threshold :  0
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.46875
# threshold :  1
# data.MGMT_value_y :  0.0
# data.MGMT_value_x :  0.25
# threshold :  0
# data.MGMT_value_y :  1.0
# [[26, 30], [34, 27]]
# Acc: 0.452991452991453 	 Recall: 0.4426229508196721
