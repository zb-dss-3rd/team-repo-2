# %%
# !nvidia-smi
# Out:
# Sun Oct 16 05:41:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install monai
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting monai
#   Downloading monai-1.0.0-202209161346-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from monai) (1.21.6)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from monai) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7->monai) (4.1.1)
# Installing collected packages: monai
# Successfully installed monai-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 5.0 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.0

# %%
import sys
import os
import cv2
import glob
import pydicom
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import time
import datetime
from dataclasses import dataclass, field
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score
from copy import deepcopy

from monai.data import CacheDataset, DataLoader
from monai.transforms import *

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(42)

class AverageMeter:
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
DATA_DIR = '/content/drive/MyDrive/PROJECT_kaggle'
MRI_TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]

# %%
MRI_TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]
excluded_imgaes = [109, 123, 709]

DATA_DIR_path = '/content/drive/MyDrive/PROJECT_kaggle'

train_df = pd.read_csv(DATA_DIR_path + "/train_df.csv")
test_df = pd.read_csv(DATA_DIR_path + '/test_df.csv')
train_df = train_df[~train_df.BraTS21ID.isin(excluded_imgaes)]

def load_dicom(path, size = 224):
    ''' 
    Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, then rescales to 0 and 255
    
    Note super sure if this kind of scaling is appropriate, but everyone seems to do it. 
    '''
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if np.max(data) != 0:
        data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return cv2.resize(data, (size, size))

def get_all_image_paths(brats21id, image_type, folder='train'): 
    '''
    Returns an arry of all the images of a particular type for a particular patient ID
    '''
    assert(image_type in MRI_TYPES)
    
    patient_path = os.path.join(
        DATA_DIR_path + "/%s/" % folder, 
        str(brats21id).zfill(5),
    )

    paths = sorted(
        glob.glob(os.path.join(patient_path, image_type, "*")), 
        key=lambda x: int(x[:-4].split("-")[-1]),
    )
    
    num_images = len(paths)
    
    start = int(num_images * 0.25)
    end = int(num_images * 0.75)

    interval = 3
    
    if num_images < 10: 
        interval = 1
    
    return np.array(paths[start:end:interval])

def get_all_images(brats21id, image_type, folder='train', size=225):
    return [load_dicom(path, size) for path in get_all_image_paths(brats21id, image_type, folder)]
IMAGE_SIZE = 128

def get_all_data_for_train(image_type):
    global train_df
    
    X = []
    y = []
    train_ids = []

    for i in tqdm(train_df.index):
        x = train_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        label = x['MGMT_value']

        X += images
        y += [label] * len(images)
        train_ids += [int(x['BraTS21ID'])] * len(images)
        assert(len(X) == len(y))
    return np.array(X), np.array(y), np.array(train_ids)

def get_all_data_for_test(image_type):
    global train_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

def get_all_data_for_val(image_type):
    global test_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

X, y, trainidt = get_all_data_for_train('T1wCE')
X_test, testidt = get_all_data_for_test('T1wCE')
X.shape, y.shape, trainidt.shape
# Out:
# 100%|██████████| 466/466 [02:50<00:00,  2.74it/s]
# 100%|██████████| 117/117 [00:45<00:00,  2.60it/s]
# ((12832, 128, 128), (12832,), (12832,))

# %%
train_df
# Out:
#      BraTS21ID  MGMT_value
# 0          185           1
# 1          816           1
# 2          707           1
# 3          683           0
# 4            6           1
# ..         ...         ...
# 463        356           0
# 464         89           1
# 465        217           0
# 466        834           0
# 467        708           1
#
# [466 rows x 2 columns]

# %%
test_df
# Out:
#      BraTS21ID  MGMT_value
# 0          107           1
# 1          753           0
# 2          303           1
# 3          106           1
# 4          171           1
# ..         ...         ...
# 112        703           0
# 113         21           0
# 114        444           0
# 115         95           0
# 116        640           1
#
# [117 rows x 2 columns]

# %%
X_train, X_valid, y_train, y_valid, trainidt_train, trainidt_valid = train_test_split(X, y, trainidt, test_size=0.2, random_state=40)

split = int(X.shape[0] * 0.8)
 
X_train = torch.Tensor(X_train)
X_valid = torch.Tensor(X_valid)

X_train = torch.unsqueeze(X_train, -1).size()
X_valid = torch.unsqueeze(X_valid, -1).size()

y_train = torch.Tensor(y_train)
y_valid = torch.Tensor(y_valid)


# X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, trainidt_train.shape, trainidt_valid.shape
X_train, y_train, X_valid, y_valid, trainidt_train, trainidt_valid
# Out:
# (torch.Size([10265, 128, 128, 1]),
#  tensor([0., 0., 0.,  ..., 1., 1., 1.]),
#  torch.Size([2567, 128, 128, 1]),
#  tensor([1., 0., 0.,  ..., 0., 1., 1.]),
#  array([1010,  649,  378, ...,  638,  485,   58]),
#  array([ 52, 657, 514, ..., 346, 468,  11]))

# %% [markdown]
# Dataset

# %%
class BrainTumorDataset(CacheDataset):
    def __init__(self, root_dir, patient_ids, mri_types, annotations, section, *args, **kwargs):
        self.root_dir = root_dir
        self.patient_ids = patient_ids
        self.mri_types = mri_types
        self.annotations = annotations
        data = self.get_data()
        if section is not None:
            train_data, val_data = train_test_split(data, test_size=0.2, random_state=42)
            data = train_data if section=='train' else val_data
        super(BrainTumorDataset, self).__init__(data, *args, **kwargs)
    
    def get_data(self):
        data = []
        for patient_id in tqdm(self.patient_ids):
            if self.annotations is not None:
                label = self.annotations[self.annotations['BraTS21ID'] 
                                         == int(patient_id)]['MGMT_value'].item()
            else:
                label = 0 # dummy value
            for slice_path in self.get_patient_slice_paths(patient_id):
                data.append({
                    'image': slice_path,
                    'label': label,
                    'patient_id': patient_id
                })
        return data
    
    def get_patient_slice_paths(self, patient_id):
        '''
        Returns an array of all the images of a particular type for a particular patient ID
        '''
        assert(set(self.mri_types) <= set(MRI_TYPES))
        patient_path = os.path.join(self.root_dir, str(patient_id).zfill(5))
        patient_slice_paths = []
        for mri_type in self.mri_types:
            paths = sorted(
                glob.glob(os.path.join(patient_path, mri_type, "*.dcm")), 
                key=lambda x: (x[:-4].split("-")[-1]),
            )

            num_images = len(paths)
            start = int(num_images * 0.25)
            end = int(num_images * 0.75)

            interval = 3
            if num_images < 10: 
                interval = 1
            patient_slice_paths.extend(paths[start:end:interval])
        return patient_slice_paths
    
class LoadDicomd(MapTransform):
    def __init__(self, img_size, *args, **kwargs):
        self.img_size = img_size
        super(LoadDicomd, self).__init__(*args, **kwargs)
    
    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            d[key] = self.load_dicom(d[key])
        return d

    def load_dicom(self, path):
        ''' 
        Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, 
        then rescales to 0 and 255
        '''
        dicom = pydicom.read_file(path)
        data = dicom.pixel_array
        if np.max(data) != 0:
            data = data / np.max(data)
        data = (data * 255).astype(np.uint8)
        data = cv2.resize(data, (self.img_size, self.img_size)) / 255
        return np.expand_dims(data, axis=0)

# %% [markdown]
# Model

# %%
class Simple2dCNN(nn.Module):
    def __init__(self, 
                 input_channels=1, 
                 n_classes=2, 
                 img_size=32, 
                 conv1_filters=128,
                 conv2_filters=64,
                 dropout_prob=0.1,
                 fc1_units=48):
        super(Simple2dCNN, self).__init__()
        
        self.relu = nn.ReLU()
        
        self.conv1 = nn.Conv2d(input_channels, conv1_filters, 4)
        self.maxpool1 = nn.MaxPool2d(2)
        
        self.conv2 = nn.Conv2d(conv1_filters, conv2_filters, 2)
        self.maxpool2 = nn.MaxPool2d(1)
        
        self.dropout = nn.Dropout(dropout_prob)
        last_feature_map_size = (img_size - 3) // 2 - 1
        self.fc1 = nn.Linear(conv2_filters * last_feature_map_size**2, fc1_units)
        self.fc2 = nn.Linear(fc1_units, n_classes)

    def forward(self, x):
        # (None, 1, 32, 32)
        x = self.relu(self.conv1(x)) # (None, 128, 29, 29)
        x = self.maxpool1(x) # (None, 128, 14, 14)
        
        x = self.relu(self.conv2(x)) # (None, 64, 13, 13)
        x = self.maxpool2(x) # (None, 64, 13, 13)
        
        x = self.dropout(x)
        x = x.view(x.size(0), -1) # (None, 64 * 13 * 13)
        x = self.relu(self.fc1(x)) # (None, 48)
        x = self.fc2(x) # (None, 2)
        return x

# %%
model = Simple2dCNN()

# %%
print(model)
# Out:
# Simple2dCNN(
#   (relu): ReLU()
#   (conv1): Conv2d(1, 128, kernel_size=(4, 4), stride=(1, 1))
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(128, 64, kernel_size=(2, 2), stride=(1, 1))
#   (maxpool2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=10816, out_features=48, bias=True)
#   (fc2): Linear(in_features=48, out_features=2, bias=True)
# )

# %% [markdown]
# Pipeline

# %%
@dataclass
class Config:
    train_dir: str = os.path.join(DATA_DIR_path, 'train')
    test_dir: str = os.path.join(DATA_DIR_path, 'train')
    annotation_path: str = os.path.join(DATA_DIR, 'train_df.csv')
    n_classes: int = 2
    img_size: int = 32
    n_workers: int = 4
    early_stopping_rounds: int = 3
    n_folds: int = 5
        
        
class Pipeline:
    def __init__(self, config):
        self.args = config
        self.device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
        self.annotations = None
        self.model = None
        self.load_model()
        # transforms
        self.preaugment_transform = [
            LoadDicomd(keys="image", img_size=self.args.img_size),
        ]
        self.augment_transform = [] # todo: add some augmentations
        self.postaugment_transform = [
            ToTensord(keys="image", dtype=torch.float),
            ToTensord(keys="label", dtype=torch.int64),
        ]
        
    def load_annotations(self):
        self.annotations = pd.read_csv(self.args.annotation_path)
        # exclude 3 cases
        self.annotations = self.annotations[~self.annotations['BraTS21ID'].isin([109, 123, 709])]
        self.annotations = self.annotations.reset_index(drop=True)
        skf = StratifiedKFold(n_splits=self.args.n_folds, shuffle=True, random_state=42)
        # split by patient, stratify based on target value
        folds = skf.split(self.annotations['BraTS21ID'].values, self.annotations['MGMT_value'].values)
        for i, (train_indices, val_indices) in enumerate(folds):
            self.annotations.loc[val_indices, 'fold'] = i
        self.annotations['fold'] = self.annotations['fold'].astype(int)
    
    def load_model(self, weights_path=None):
        self.model = Simple2dCNN(input_channels=1, 
                                 n_classes=self.args.n_classes,
                                 img_size=self.args.img_size).to(self.device)
        if weights_path:
            weights = torch.load(weights_path, map_location=self.device)
            self.model.load_state_dict(weights)
        
    def prepare_datasets(self, mri_types, fold, cache_rate):
        """
        Data format:
        {
            'image': torch tensor (batch_size, 1, 32, 32),
            'label': torch tensor (batch_size, )
            'patient_id'
        }
        Output: torch tensor (batch_size, 2)
        """
        train_transform = Compose(
            self.preaugment_transform +
            self.augment_transform +
            self.postaugment_transform
        )
        val_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        
        train_ids = self.annotations[self.annotations['fold']!=fold]['BraTS21ID'].values.tolist()
        val_holdout_ids = self.annotations[self.annotations['fold']==fold]['BraTS21ID'].values.tolist()
        
        train_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                     patient_ids=train_ids, 
                                     mri_types=mri_types,  
                                     annotations=self.annotations,
                                     transform=train_transform,
                                     section='train',
                                     cache_rate=cache_rate,
                                     num_workers=self.args.n_workers)
        val_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                   patient_ids=train_ids, 
                                   mri_types=mri_types,  
                                   annotations=self.annotations,
                                   transform=val_transform,
                                   section='val',
                                   cache_rate=cache_rate,
                                   num_workers=self.args.n_workers)
        val_holdout_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                           patient_ids=val_holdout_ids, 
                                           mri_types=mri_types, 
                                           annotations=self.annotations, 
                                           transform=val_transform,
                                           section=None,
                                           cache_rate=cache_rate,
                                           num_workers=self.args.n_workers)
        return train_ds, val_ds, val_holdout_ds
    
    def prepare_test_dataset(self, mri_types, cache_rate):
        test_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        test_ids = [int(patient_id) for patient_id in os.listdir(self.args.test_dir)]
        test_ids = sorted(test_ids, key=lambda x: int(x))
        test_ds = BrainTumorDataset(root_dir=self.args.test_dir, 
                                    patient_ids=test_ids, 
                                    mri_types=mri_types, 
                                    annotations=None, 
                                    transform=test_transform,
                                    section=None,
                                    cache_rate=cache_rate,
                                    num_workers=self.args.n_workers)
        return test_ds
    
    def train_epoch(self, loader, loss_function, optimizer, verbose):
        self.model.train()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        for step, batch_data in enumerate(loader):
            inputs, labels = (
                batch_data["image"].to(self.device), # (None, 1, 32, 32)
                batch_data["label"].to(self.device), # (None, )
            )
            batch_size = inputs.size(0)
            # back propagation
            optimizer.zero_grad()
            outputs = self.model(inputs) # (None, 2)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            # update stats
            summary_loss.update(loss.item(), batch_size)
            if verbose:
                print('Train step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                              summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Train loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        return summary_loss.avg
    
    def evaluate_epoch(self, loader, loss_function, verbose):
        self.model.eval()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        labels_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, labels, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["label"].to(self.device), # (None, )
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # back propagation
                outputs = self.model(inputs) # (None, 2)
                loss = loss_function(outputs, labels)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                labels_all.extend(labels.tolist())
                patient_ids_all.extend(patient_ids)
                
                summary_loss.update(loss.item(), batch_size)
                if verbose:
                    print('Val step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                                summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Val loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
            'label': labels_all
        }
        result = pd.DataFrame(result)
        slice_auc = roc_auc_score(result['label'], result['probability'])
        result = result.groupby("BraTS21ID", as_index=False).mean()
        patient_auc = roc_auc_score(result['label'], result['probability'])
        print('Patient AUC: {:.5f} - Slice AUC: {:.5f}'.format(patient_auc, slice_auc))
        
        return summary_loss.avg, patient_auc, result
    
    def infer_epoch(self, loader, verbose):
        self.model.eval()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # forward
                outputs = self.model(inputs) # (None, 2)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                patient_ids_all.extend(patient_ids)
                if verbose:
                    print('Infer step {}/{}'.format(step + 1, n), end='\r')
        
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
        }
        result = pd.DataFrame(result)
        result = result.groupby("BraTS21ID", as_index=False).mean()
        
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Elapsed time: {}'.format(elapsed_time))
        
        return result
    
    def fit(self, train_ds, val_ds, val_holdout_ds, batch_size, epochs, lr, model_name, verbose):
        train_loader = DataLoader(train_ds, 
                                  batch_size=batch_size, 
                                  shuffle=True,
                                  num_workers=self.args.n_workers)
        val_loader = DataLoader(val_ds, 
                                batch_size=batch_size, 
                                shuffle=False,
                                num_workers=self.args.n_workers)
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        
        current_metric = -np.inf
        current_loss = np.inf
        current_epoch = 1
        current_state_dict = None
        save_path = '{}_imgsize{}_valloss{:.3f}_valauc{:.3f}.pth'
        for epoch in range(1, epochs + 1):
            print('\nEpoch {}/{}:'.format(epoch, epochs))
            train_loss = self.train_epoch(train_loader, loss_function, optimizer, verbose)
            print(' Validation:')
            val_loss, val_metric, _ = self.evaluate_epoch(val_loader, loss_function, verbose)
            print(' Hold out:')
            val_holdout_loss, val_holdout_metric, _ = self.evaluate_epoch(val_holdout_loader, 
                                                                          loss_function, 
                                                                          verbose)
            
#             if val_loss < current_loss:
            if val_metric > current_metric:
                print('Val AUC improved from {:.5f} to {:.5f}'.format(current_metric, val_metric))
                current_metric = val_metric
                current_loss = val_loss
                current_epoch = epoch
                current_state_dict = deepcopy(self.model.state_dict())
                
            elif (epoch - current_epoch) > self.args.early_stopping_rounds:
                print('Early stopping. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                break
            if epoch == epochs:
                print('Finished training. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                
    def evaluate(self, val_holdout_ds, batch_size, verbose):
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        print(' Hold out:')
        _, val_holdout_metric, val_holdout_result = self.evaluate_epoch(val_holdout_loader, 
                                                                        loss_function, 
                                                                        verbose)
        return val_holdout_metric, val_holdout_result
    
    def predict(self, test_ds, batch_size, verbose):
        test_loader = DataLoader(test_ds, 
                                 batch_size=batch_size, 
                                 shuffle=False,
                                 num_workers=self.args.n_workers)
        test_result = self.infer_epoch(test_loader, verbose)
        return test_result

# %%
mri_types = ['T1wCE']
img_size = 16 #32
batch_size = 32
n_workers = 4
early_stopping_rounds = 3
n_folds = 5
epochs = 40 #50
lr = 1e-3

# %%
args = Config(img_size=img_size, 
              n_workers=n_workers, 
              early_stopping_rounds=early_stopping_rounds,
              n_folds=n_folds)
pipeline = Pipeline(args)

# %% [markdown]
# Train

# %%
# %%time
pipeline.load_annotations()
for fold in range(n_folds):
    print(f'### Train {mri_types} on fold {fold}: ###')
    train_ds, val_ds, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                                 fold=fold,
                                                                 cache_rate=1.0)
    pipeline.load_model()
    pipeline.fit(train_ds, val_ds, val_holdout_ds,
                 batch_size=batch_size, epochs=epochs, lr=lr, 
                 model_name=f'{"_".join(mri_types)}_fold{fold}',
                 verbose=True)
# Out:
# ### Train ['T1wCE'] on fold 0: ###
# 100%|██████████| 372/372 [00:01<00:00, 310.73it/s]
# Loading dataset: 100%|██████████| 8245/8245 [00:27<00:00, 302.13it/s]
# 100%|██████████| 372/372 [00:01<00:00, 297.70it/s]
# Loading dataset: 100%|██████████| 2062/2062 [00:06<00:00, 296.63it/s]
# 100%|██████████| 94/94 [00:00<00:00, 304.79it/s]
# Loading dataset: 100%|██████████| 2525/2525 [00:08<00:00, 302.02it/s]
# Epoch 1/40:
# Train loss: 0.68355 - time: 0:00:11.641119
#  Validation:
# Val loss: 0.68745 - time: 0:00:00.815083
# Patient AUC: 0.59263 - Slice AUC: 0.55945
#  Hold out:
# Val loss: 0.72193 - time: 0:00:00.911635
# Patient AUC: 0.46909 - Slice AUC: 0.49627
# Val AUC improved from -inf to 0.59263
#
# Epoch 2/40:
# Train loss: 0.67390 - time: 0:00:02.682613
#  Validation:
# Val loss: 0.66884 - time: 0:00:00.837492
# Patient AUC: 0.65073 - Slice AUC: 0.60152
#  Hold out:
# Val loss: 0.71262 - time: 0:00:00.916960
# Patient AUC: 0.44636 - Slice AUC: 0.48162
# Val AUC improved from 0.59263 to 0.65073
#
# Epoch 3/40:
# Train loss: 0.67140 - time: 0:00:02.756412
#  Validation:
# Val loss: 0.66354 - time: 0:00:00.842722
# Patient AUC: 0.66059 - Slice AUC: 0.60445
#  Hold out:
# Val loss: 0.71782 - time: 0:00:00.927150
# Patient AUC: 0.43818 - Slice AUC: 0.48062
# Val AUC improved from 0.65073 to 0.66059
#
# Epoch 4/40:
# Train loss: 0.66777 - time: 0:00:02.707593
#  Validation:
# Val loss: 0.66964 - time: 0:00:00.814863
# Patient AUC: 0.63942 - Slice AUC: 0.59990
#  Hold out:
# Val loss: 0.73443 - time: 0:00:00.930616
# Patient AUC: 0.43955 - Slice AUC: 0.47514
#
# Epoch 5/40:
# Train loss: 0.66466 - time: 0:00:02.689487
#  Validation:
# Val loss: 0.65978 - time: 0:00:00.826732
# Patient AUC: 0.67557 - Slice AUC: 0.60590
#  Hold out:
# Val loss: 0.75105 - time: 0:00:00.962972
# Patient AUC: 0.42955 - Slice AUC: 0.48339
# Val AUC improved from 0.66059 to 0.67557
#
# Epoch 6/40:
# Train loss: 0.66231 - time: 0:00:02.735022
#  Validation:
# Val loss: 0.65758 - time: 0:00:00.798165
# Patient AUC: 0.67284 - Slice AUC: 0.61082
#  Hold out:
# Val loss: 0.75628 - time: 0:00:00.916272
# Patient AUC: 0.43364 - Slice AUC: 0.48430
#
# Epoch 7/40:
# Train loss: 0.65856 - time: 0:00:02.713832
#  Validation:
# Val loss: 0.65372 - time: 0:00:00.835986
# Patient AUC: 0.68234 - Slice AUC: 0.61634
#  Hold out:
# Val loss: 0.75253 - time: 0:00:00.927139
# Patient AUC: 0.40591 - Slice AUC: 0.46267
# Val AUC improved from 0.67557 to 0.68234
#
# Epoch 8/40:
# Train loss: 0.65580 - time: 0:00:02.764059
#  Validation:
# Val loss: 0.65063 - time: 0:00:00.825887
# Patient AUC: 0.68231 - Slice AUC: 0.61744
#  Hold out:
# Val loss: 0.77796 - time: 0:00:00.924397
# Patient AUC: 0.42318 - Slice AUC: 0.47044
#
# Epoch 9/40:
# Train loss: 0.64977 - time: 0:00:02.750013
#  Validation:
# Val loss: 0.65169 - time: 0:00:00.843839
# Patient AUC: 0.68139 - Slice AUC: 0.62803
#  Hold out:
# Val loss: 0.76501 - time: 0:00:00.938599
# Patient AUC: 0.41227 - Slice AUC: 0.47459
#
# Epoch 10/40:
# Train loss: 0.64561 - time: 0:00:02.763598
#  Validation:
# Val loss: 0.64674 - time: 0:00:00.835301
# Patient AUC: 0.70114 - Slice AUC: 0.63351
#  Hold out:
# Val loss: 0.78383 - time: 0:00:00.935782
# Patient AUC: 0.41545 - Slice AUC: 0.47063
# Val AUC improved from 0.68234 to 0.70114
#
# Epoch 11/40:
# Train loss: 0.64369 - time: 0:00:03.082284
#  Validation:
# Val loss: 0.64483 - time: 0:00:00.833352
# Patient AUC: 0.70768 - Slice AUC: 0.64294
#  Hold out:
# Val loss: 0.77649 - time: 0:00:00.927751
# Patient AUC: 0.41727 - Slice AUC: 0.48375
# Val AUC improved from 0.70114 to 0.70768
#
# Epoch 12/40:
# Train loss: 0.63737 - time: 0:00:02.692226
#  Validation:
# Val loss: 0.64669 - time: 0:00:00.840317
# Patient AUC: 0.68865 - Slice AUC: 0.63810
#  Hold out:
# Val loss: 0.79549 - time: 0:00:00.934121
# Patient AUC: 0.40364 - Slice AUC: 0.47132
#
# Epoch 13/40:
# Train loss: 0.63003 - time: 0:00:02.671614
#  Validation:
# Val loss: 0.64037 - time: 0:00:00.810256
# Patient AUC: 0.71448 - Slice AUC: 0.64783
#  Hold out:
# Val loss: 0.81377 - time: 0:00:00.918470
# Patient AUC: 0.41682 - Slice AUC: 0.46930
# Val AUC improved from 0.70768 to 0.71448
#
# Epoch 14/40:
# Train loss: 0.62174 - time: 0:00:02.728097
#  Validation:
# Val loss: 0.64072 - time: 0:00:00.813661
# Patient AUC: 0.72227 - Slice AUC: 0.64866
#  Hold out:
# Val loss: 0.84863 - time: 0:00:00.922101
# Patient AUC: 0.42682 - Slice AUC: 0.47846
# Val AUC improved from 0.71448 to 0.72227
#
# Epoch 15/40:
# Train loss: 0.61734 - time: 0:00:02.768772
#  Validation:
# Val loss: 0.63678 - time: 0:00:00.840079
# Patient AUC: 0.73427 - Slice AUC: 0.64515
#  Hold out:
# Val loss: 0.85787 - time: 0:00:00.921550
# Patient AUC: 0.40500 - Slice AUC: 0.46106
# Val AUC improved from 0.72227 to 0.73427
#
# Epoch 16/40:
# Train loss: 0.61041 - time: 0:00:02.742322
#  Validation:
# Val loss: 0.63090 - time: 0:00:00.822701
# Patient AUC: 0.74429 - Slice AUC: 0.66231
#  Hold out:
# Val loss: 0.85975 - time: 0:00:00.914600
# Patient AUC: 0.41909 - Slice AUC: 0.47700
# Val AUC improved from 0.73427 to 0.74429
#
# Epoch 17/40:
# Train loss: 0.60315 - time: 0:00:02.707381
#  Validation:
# Val loss: 0.63479 - time: 0:00:00.801121
# Patient AUC: 0.75329 - Slice AUC: 0.65066
#  Hold out:
# Val loss: 0.90165 - time: 0:00:00.938643
# Patient AUC: 0.41591 - Slice AUC: 0.46746
# Val AUC improved from 0.74429 to 0.75329
#
# Epoch 18/40:
# Train loss: 0.59558 - time: 0:00:02.692855
#  Validation:
# Val loss: 0.63341 - time: 0:00:00.821004
# Patient AUC: 0.74738 - Slice AUC: 0.66248
#  Hold out:
# Val loss: 0.92370 - time: 0:00:00.927061
# Patient AUC: 0.42091 - Slice AUC: 0.47644
#
# Epoch 19/40:
# Train loss: 0.59226 - time: 0:00:02.762330
#  Validation:
# Val loss: 0.62658 - time: 0:00:00.826714
# Patient AUC: 0.75297 - Slice AUC: 0.66777
#  Hold out:
# Val loss: 0.93393 - time: 0:00:00.924104
# Patient AUC: 0.41227 - Slice AUC: 0.46713
#
# Epoch 20/40:
# Train loss: 0.58407 - time: 0:00:02.700593
#  Validation:
# Val loss: 0.64996 - time: 0:00:00.823576
# Patient AUC: 0.74445 - Slice AUC: 0.65502
#  Hold out:
# Val loss: 0.93819 - time: 0:00:00.908667
# Patient AUC: 0.42364 - Slice AUC: 0.47314
#
# Epoch 21/40:
# Train loss: 0.58026 - time: 0:00:02.740202
#  Validation:
# Val loss: 0.62717 - time: 0:00:00.837529
# Patient AUC: 0.76795 - Slice AUC: 0.66991
#  Hold out:
# Val loss: 0.95289 - time: 0:00:00.976651
# Patient AUC: 0.45182 - Slice AUC: 0.47372
# Val AUC improved from 0.75329 to 0.76795
#
# Epoch 22/40:
# Train loss: 0.57243 - time: 0:00:02.721250
#  Validation:
# Val loss: 0.63755 - time: 0:00:00.812327
# Patient AUC: 0.76608 - Slice AUC: 0.66363
#  Hold out:
# Val loss: 1.04018 - time: 0:00:00.919217
# Patient AUC: 0.43591 - Slice AUC: 0.47047
#
# Epoch 23/40:
# Train loss: 0.56623 - time: 0:00:02.731028
#  Validation:
# Val loss: 0.63077 - time: 0:00:00.819573
# Patient AUC: 0.77163 - Slice AUC: 0.67146
#  Hold out:
# Val loss: 0.98517 - time: 0:00:00.924995
# Patient AUC: 0.42864 - Slice AUC: 0.46749
# Val AUC improved from 0.76795 to 0.77163
#
# Epoch 24/40:
# Train loss: 0.56302 - time: 0:00:02.724881
#  Validation:
# Val loss: 0.63188 - time: 0:00:00.794727
# Patient AUC: 0.76329 - Slice AUC: 0.66696
#  Hold out:
# Val loss: 1.04489 - time: 0:00:00.927855
# Patient AUC: 0.39045 - Slice AUC: 0.44298
#
# Epoch 25/40:
# Train loss: 0.56047 - time: 0:00:02.721555
#  Validation:
# Val loss: 0.62160 - time: 0:00:00.834862
# Patient AUC: 0.77840 - Slice AUC: 0.67124
#  Hold out:
# Val loss: 1.00525 - time: 0:00:00.934183
# Patient AUC: 0.44045 - Slice AUC: 0.47564
# Val AUC improved from 0.77163 to 0.77840
#
# Epoch 26/40:
# Train loss: 0.55102 - time: 0:00:02.777059
#  Validation:
# Val loss: 0.63993 - time: 0:00:00.825527
# Patient AUC: 0.76867 - Slice AUC: 0.65604
#  Hold out:
# Val loss: 0.99981 - time: 0:00:00.941154
# Patient AUC: 0.42136 - Slice AUC: 0.47613
#
# Epoch 27/40:
# Train loss: 0.54415 - time: 0:00:02.711337
#  Validation:
# Val loss: 0.63977 - time: 0:00:00.802331
# Patient AUC: 0.77544 - Slice AUC: 0.67340
#  Hold out:
# Val loss: 1.17482 - time: 0:00:00.927227
# Patient AUC: 0.46318 - Slice AUC: 0.46711
#
# Epoch 28/40:
# Train loss: 0.54068 - time: 0:00:02.777195
#  Validation:
# Val loss: 0.63208 - time: 0:00:00.839944
# Patient AUC: 0.79355 - Slice AUC: 0.66999
#  Hold out:
# Val loss: 1.16614 - time: 0:00:00.942265
# Patient AUC: 0.44136 - Slice AUC: 0.46616
# Val AUC improved from 0.77840 to 0.79355
#
# Epoch 29/40:
# Train loss: 0.53625 - time: 0:00:02.724545
#  Validation:
# Val loss: 0.62675 - time: 0:00:00.838788
# Patient AUC: 0.78304 - Slice AUC: 0.67461
#  Hold out:
# Val loss: 1.10135 - time: 0:00:00.924958
# Patient AUC: 0.43045 - Slice AUC: 0.46643
#
# Epoch 30/40:
# Train loss: 0.52821 - time: 0:00:02.722710
#  Validation:
# Val loss: 0.64197 - time: 0:00:00.833472
# Patient AUC: 0.78974 - Slice AUC: 0.67367
#  Hold out:
# Val loss: 1.20239 - time: 0:00:00.938212
# Patient AUC: 0.43091 - Slice AUC: 0.47024
#
# Epoch 31/40:
# Train loss: 0.52663 - time: 0:00:02.750469
#  Validation:
# Val loss: 0.65588 - time: 0:00:00.826844
# Patient AUC: 0.78898 - Slice AUC: 0.67716
#  Hold out:
# Val loss: 1.23819 - time: 0:00:00.919388
# Patient AUC: 0.43409 - Slice AUC: 0.46337
#
# Epoch 32/40:
# Train loss: 0.51935 - time: 0:00:02.723608
#  Validation:
# Val loss: 0.65393 - time: 0:00:00.812555
# Patient AUC: 0.77406 - Slice AUC: 0.68063
#  Hold out:
# Val loss: 1.23922 - time: 0:00:00.972116
# Patient AUC: 0.40227 - Slice AUC: 0.45996
# Early stopping. Best model is epoch 28
# Val loss: 0.63208, Val auc: 0.79355
# Saving model...
# ### Train ['T1wCE'] on fold 1: ###
# 100%|██████████| 373/373 [00:01<00:00, 297.30it/s]
# Loading dataset: 100%|██████████| 8336/8336 [00:27<00:00, 298.13it/s]
# 100%|██████████| 373/373 [00:01<00:00, 251.77it/s]
# Loading dataset: 100%|██████████| 2084/2084 [00:07<00:00, 280.52it/s]
# 100%|██████████| 93/93 [00:00<00:00, 319.21it/s]
# Loading dataset: 100%|██████████| 2412/2412 [00:08<00:00, 293.98it/s]
# Epoch 1/40:
# Train loss: 0.68906 - time: 0:00:02.883006
#  Validation:
# Val loss: 0.68341 - time: 0:00:00.846174
# Patient AUC: 0.57965 - Slice AUC: 0.56117
#  Hold out:
# Val loss: 0.67697 - time: 0:00:00.924753
# Patient AUC: 0.72171 - Slice AUC: 0.63722
# Val AUC improved from -inf to 0.57965
#
# Epoch 2/40:
# Train loss: 0.68491 - time: 0:00:02.737656
#  Validation:
# Val loss: 0.68338 - time: 0:00:00.840208
# Patient AUC: 0.58273 - Slice AUC: 0.56023
#  Hold out:
# Val loss: 0.67793 - time: 0:00:00.910671
# Patient AUC: 0.72171 - Slice AUC: 0.60936
# Val AUC improved from 0.57965 to 0.58273
#
# Epoch 3/40:
# Train loss: 0.68252 - time: 0:00:02.844179
#  Validation:
# Val loss: 0.67932 - time: 0:00:00.861555
# Patient AUC: 0.59464 - Slice AUC: 0.56663
#  Hold out:
# Val loss: 0.67152 - time: 0:00:00.982299
# Patient AUC: 0.70455 - Slice AUC: 0.61541
# Val AUC improved from 0.58273 to 0.59464
#
# Epoch 4/40:
# Train loss: 0.68094 - time: 0:00:02.830863
#  Validation:
# Val loss: 0.67849 - time: 0:00:00.859633
# Patient AUC: 0.58474 - Slice AUC: 0.56407
#  Hold out:
# Val loss: 0.67412 - time: 0:00:00.925097
# Patient AUC: 0.69481 - Slice AUC: 0.60145
#
# Epoch 5/40:
# Train loss: 0.67973 - time: 0:00:02.875558
#  Validation:
# Val loss: 0.67759 - time: 0:00:00.840480
# Patient AUC: 0.59387 - Slice AUC: 0.56483
#  Hold out:
# Val loss: 0.67470 - time: 0:00:00.932863
# Patient AUC: 0.69573 - Slice AUC: 0.59815
#
# Epoch 6/40:
# Train loss: 0.67860 - time: 0:00:02.776411
#  Validation:
# Val loss: 0.68065 - time: 0:00:00.842706
# Patient AUC: 0.59839 - Slice AUC: 0.57260
#  Hold out:
# Val loss: 0.68033 - time: 0:00:00.935153
# Patient AUC: 0.68460 - Slice AUC: 0.61086
# Val AUC improved from 0.59464 to 0.59839
#
# Epoch 7/40:
# Train loss: 0.67571 - time: 0:00:02.763443
#  Validation:
# Val loss: 0.68073 - time: 0:00:00.853320
# Patient AUC: 0.59570 - Slice AUC: 0.56372
#  Hold out:
# Val loss: 0.67714 - time: 0:00:00.931102
# Patient AUC: 0.67022 - Slice AUC: 0.58869
#
# Epoch 8/40:
# Train loss: 0.67346 - time: 0:00:02.800658
#  Validation:
# Val loss: 0.67163 - time: 0:00:00.891548
# Patient AUC: 0.61549 - Slice AUC: 0.58272
#  Hold out:
# Val loss: 0.67696 - time: 0:00:00.912078
# Patient AUC: 0.69202 - Slice AUC: 0.59162
# Val AUC improved from 0.59839 to 0.61549
#
# Epoch 9/40:
# Train loss: 0.66972 - time: 0:00:02.733017
#  Validation:
# Val loss: 0.67231 - time: 0:00:00.845082
# Patient AUC: 0.61696 - Slice AUC: 0.58535
#  Hold out:
# Val loss: 0.68858 - time: 0:00:00.906959
# Patient AUC: 0.63544 - Slice AUC: 0.57935
# Val AUC improved from 0.61549 to 0.61696
#
# Epoch 10/40:
# Train loss: 0.66553 - time: 0:00:02.835593
#  Validation:
# Val loss: 0.66795 - time: 0:00:00.857716
# Patient AUC: 0.63358 - Slice AUC: 0.59317
#  Hold out:
# Val loss: 0.68638 - time: 0:00:00.913463
# Patient AUC: 0.66929 - Slice AUC: 0.56309
# Val AUC improved from 0.61696 to 0.63358
#
# Epoch 11/40:
# Train loss: 0.66349 - time: 0:00:02.760889
#  Validation:
# Val loss: 0.66865 - time: 0:00:00.849164
# Patient AUC: 0.65487 - Slice AUC: 0.59892
#  Hold out:
# Val loss: 0.68921 - time: 0:00:00.907588
# Patient AUC: 0.62941 - Slice AUC: 0.56763
# Val AUC improved from 0.63358 to 0.65487
#
# Epoch 12/40:
# Train loss: 0.66000 - time: 0:00:02.749784
#  Validation:
# Val loss: 0.66318 - time: 0:00:00.867836
# Patient AUC: 0.65996 - Slice AUC: 0.60940
#  Hold out:
# Val loss: 0.68414 - time: 0:00:00.921707
# Patient AUC: 0.64889 - Slice AUC: 0.59009
# Val AUC improved from 0.65487 to 0.65996
#
# Epoch 13/40:
# Train loss: 0.65204 - time: 0:00:02.753806
#  Validation:
# Val loss: 0.66532 - time: 0:00:00.858493
# Patient AUC: 0.65654 - Slice AUC: 0.61051
#  Hold out:
# Val loss: 0.69431 - time: 0:00:00.919604
# Patient AUC: 0.61781 - Slice AUC: 0.55833
#
# Epoch 14/40:
# Train loss: 0.64746 - time: 0:00:02.742907
#  Validation:
# Val loss: 0.66896 - time: 0:00:00.828493
# Patient AUC: 0.64914 - Slice AUC: 0.60239
#  Hold out:
# Val loss: 0.69172 - time: 0:00:00.914979
# Patient AUC: 0.71382 - Slice AUC: 0.59970
#
# Epoch 15/40:
# Train loss: 0.64227 - time: 0:00:02.810295
#  Validation:
# Val loss: 0.68690 - time: 0:00:00.847583
# Patient AUC: 0.64642 - Slice AUC: 0.60884
#  Hold out:
# Val loss: 0.73383 - time: 0:00:00.915927
# Patient AUC: 0.69156 - Slice AUC: 0.57399
#
# Epoch 16/40:
# Train loss: 0.63686 - time: 0:00:02.717511
#  Validation:
# Val loss: 0.65676 - time: 0:00:00.854049
# Patient AUC: 0.68151 - Slice AUC: 0.62944
#  Hold out:
# Val loss: 0.71760 - time: 0:00:00.918751
# Patient AUC: 0.55798 - Slice AUC: 0.51398
# Val AUC improved from 0.65996 to 0.68151
#
# Epoch 17/40:
# Train loss: 0.63070 - time: 0:00:02.891809
#  Validation:
# Val loss: 0.65954 - time: 0:00:00.851139
# Patient AUC: 0.69772 - Slice AUC: 0.63409
#  Hold out:
# Val loss: 0.71558 - time: 0:00:00.937826
# Patient AUC: 0.65724 - Slice AUC: 0.56955
# Val AUC improved from 0.68151 to 0.69772
#
# Epoch 18/40:
# Train loss: 0.62196 - time: 0:00:02.743662
#  Validation:
# Val loss: 0.65107 - time: 0:00:00.853007
# Patient AUC: 0.71715 - Slice AUC: 0.64366
#  Hold out:
# Val loss: 0.72168 - time: 0:00:00.928767
# Patient AUC: 0.58766 - Slice AUC: 0.55014
# Val AUC improved from 0.69772 to 0.71715
#
# Epoch 19/40:
# Train loss: 0.61600 - time: 0:00:02.757106
#  Validation:
# Val loss: 0.65684 - time: 0:00:00.841070
# Patient AUC: 0.71382 - Slice AUC: 0.62883
#  Hold out:
# Val loss: 0.72695 - time: 0:00:00.916817
# Patient AUC: 0.67208 - Slice AUC: 0.57246
#
# Epoch 20/40:
# Train loss: 0.61061 - time: 0:00:02.760078
#  Validation:
# Val loss: 0.65042 - time: 0:00:00.828687
# Patient AUC: 0.72538 - Slice AUC: 0.63928
#  Hold out:
# Val loss: 0.72263 - time: 0:00:00.915514
# Patient AUC: 0.60019 - Slice AUC: 0.55079
# Val AUC improved from 0.71715 to 0.72538
#
# Epoch 21/40:
# Train loss: 0.60168 - time: 0:00:02.734363
#  Validation:
# Val loss: 0.65033 - time: 0:00:00.823273
# Patient AUC: 0.73800 - Slice AUC: 0.64839
#  Hold out:
# Val loss: 0.74404 - time: 0:00:00.940164
# Patient AUC: 0.52968 - Slice AUC: 0.52863
# Val AUC improved from 0.72538 to 0.73800
#
# Epoch 22/40:
# Train loss: 0.59788 - time: 0:00:02.746318
#  Validation:
# Val loss: 0.64372 - time: 0:00:00.838426
# Patient AUC: 0.73198 - Slice AUC: 0.65469
#  Hold out:
# Val loss: 0.74765 - time: 0:00:00.926545
# Patient AUC: 0.59276 - Slice AUC: 0.54752
#
# Epoch 23/40:
# Train loss: 0.58705 - time: 0:00:02.792941
#  Validation:
# Val loss: 0.64906 - time: 0:00:00.858682
# Patient AUC: 0.73208 - Slice AUC: 0.65319
#  Hold out:
# Val loss: 0.75434 - time: 0:00:00.920737
# Patient AUC: 0.60297 - Slice AUC: 0.55374
#
# Epoch 24/40:
# Train loss: 0.57811 - time: 0:00:02.763114
#  Validation:
# Val loss: 0.65325 - time: 0:00:00.848387
# Patient AUC: 0.72583 - Slice AUC: 0.64857
#  Hold out:
# Val loss: 0.75685 - time: 0:00:00.913093
# Patient AUC: 0.64796 - Slice AUC: 0.56924
#
# Epoch 25/40:
# Train loss: 0.57505 - time: 0:00:02.858616
#  Validation:
# Val loss: 0.65778 - time: 0:00:00.959296
# Patient AUC: 0.74175 - Slice AUC: 0.65561
#  Hold out:
# Val loss: 0.78651 - time: 0:00:01.040130
# Patient AUC: 0.58998 - Slice AUC: 0.55909
# Val AUC improved from 0.73800 to 0.74175
#
# Epoch 26/40:
# Train loss: 0.57076 - time: 0:00:02.811042
#  Validation:
# Val loss: 0.64644 - time: 0:00:00.854830
# Patient AUC: 0.73707 - Slice AUC: 0.65751
#  Hold out:
# Val loss: 0.77832 - time: 0:00:00.916024
# Patient AUC: 0.64100 - Slice AUC: 0.56228
#
# Epoch 27/40:
# Train loss: 0.55791 - time: 0:00:02.732831
#  Validation:
# Val loss: 0.63755 - time: 0:00:00.850319
# Patient AUC: 0.79272 - Slice AUC: 0.67852
#  Hold out:
# Val loss: 0.78218 - time: 0:00:00.918005
# Patient AUC: 0.59647 - Slice AUC: 0.53258
# Val AUC improved from 0.74175 to 0.79272
#
# Epoch 28/40:
# Train loss: 0.54919 - time: 0:00:02.777340
#  Validation:
# Val loss: 0.63422 - time: 0:00:00.839754
# Patient AUC: 0.77767 - Slice AUC: 0.68084
#  Hold out:
# Val loss: 0.79572 - time: 0:00:00.923379
# Patient AUC: 0.58905 - Slice AUC: 0.54030
#
# Epoch 29/40:
# Train loss: 0.54447 - time: 0:00:02.713611
#  Validation:
# Val loss: 0.64035 - time: 0:00:00.837066
# Patient AUC: 0.77575 - Slice AUC: 0.67575
#  Hold out:
# Val loss: 0.83004 - time: 0:00:00.926506
# Patient AUC: 0.50046 - Slice AUC: 0.51277
#
# Epoch 30/40:
# Train loss: 0.54042 - time: 0:00:02.843682
#  Validation:
# Val loss: 0.64145 - time: 0:00:00.866705
# Patient AUC: 0.77691 - Slice AUC: 0.67109
#  Hold out:
# Val loss: 0.78436 - time: 0:00:00.926172
# Patient AUC: 0.64564 - Slice AUC: 0.56977
#
# Epoch 31/40:
# Train loss: 0.53248 - time: 0:00:02.766483
#  Validation:
# Val loss: 0.64475 - time: 0:00:00.829118
# Patient AUC: 0.78693 - Slice AUC: 0.67961
#  Hold out:
# Val loss: 0.85758 - time: 0:00:00.914875
# Patient AUC: 0.51113 - Slice AUC: 0.52355
# Early stopping. Best model is epoch 27
# Val loss: 0.63755, Val auc: 0.79272
# Saving model...
# ### Train ['T1wCE'] on fold 2: ###
# 100%|██████████| 373/373 [00:01<00:00, 310.29it/s]
# Loading dataset: 100%|██████████| 8149/8149 [00:27<00:00, 298.26it/s]
# 100%|██████████| 373/373 [00:01<00:00, 309.21it/s]
# Loading dataset: 100%|██████████| 2038/2038 [00:07<00:00, 286.66it/s]
# 100%|██████████| 93/93 [00:00<00:00, 303.51it/s]
# Loading dataset: 100%|██████████| 2645/2645 [00:09<00:00, 288.41it/s]
# Epoch 1/40:
# Train loss: 0.69100 - time: 0:00:02.844769
#  Validation:
# Val loss: 0.68674 - time: 0:00:00.825300
# Patient AUC: 0.58748 - Slice AUC: 0.54414
#  Hold out:
# Val loss: 0.67917 - time: 0:00:00.961038
# Patient AUC: 0.70733 - Slice AUC: 0.60145
# Val AUC improved from -inf to 0.58748
#
# Epoch 2/40:
# Train loss: 0.68660 - time: 0:00:02.750431
#  Validation:
# Val loss: 0.68071 - time: 0:00:00.837731
# Patient AUC: 0.61801 - Slice AUC: 0.57590
#  Hold out:
# Val loss: 0.67626 - time: 0:00:00.959459
# Patient AUC: 0.68646 - Slice AUC: 0.58508
# Val AUC improved from 0.58748 to 0.61801
#
# Epoch 3/40:
# Train loss: 0.68438 - time: 0:00:02.646092
#  Validation:
# Val loss: 0.68006 - time: 0:00:00.817813
# Patient AUC: 0.62384 - Slice AUC: 0.57785
#  Hold out:
# Val loss: 0.67912 - time: 0:00:00.978538
# Patient AUC: 0.68506 - Slice AUC: 0.58750
# Val AUC improved from 0.61801 to 0.62384
#
# Epoch 4/40:
# Train loss: 0.68365 - time: 0:00:02.748641
#  Validation:
# Val loss: 0.67955 - time: 0:00:00.841828
# Patient AUC: 0.62888 - Slice AUC: 0.57204
#  Hold out:
# Val loss: 0.66818 - time: 0:00:00.958516
# Patient AUC: 0.69063 - Slice AUC: 0.60524
# Val AUC improved from 0.62384 to 0.62888
#
# Epoch 5/40:
# Train loss: 0.67995 - time: 0:00:02.726115
#  Validation:
# Val loss: 0.67865 - time: 0:00:00.834011
# Patient AUC: 0.61792 - Slice AUC: 0.58118
#  Hold out:
# Val loss: 0.67027 - time: 0:00:00.964892
# Patient AUC: 0.68460 - Slice AUC: 0.59057
#
# Epoch 6/40:
# Train loss: 0.68025 - time: 0:00:02.719577
#  Validation:
# Val loss: 0.67747 - time: 0:00:00.826320
# Patient AUC: 0.62295 - Slice AUC: 0.58015
#  Hold out:
# Val loss: 0.67109 - time: 0:00:01.000062
# Patient AUC: 0.68924 - Slice AUC: 0.59815
#
# Epoch 7/40:
# Train loss: 0.67948 - time: 0:00:02.732534
#  Validation:
# Val loss: 0.67821 - time: 0:00:00.842885
# Patient AUC: 0.62777 - Slice AUC: 0.58001
#  Hold out:
# Val loss: 0.67793 - time: 0:00:00.970218
# Patient AUC: 0.67208 - Slice AUC: 0.58008
#
# Epoch 8/40:
# Train loss: 0.67609 - time: 0:00:02.721141
#  Validation:
# Val loss: 0.68049 - time: 0:00:00.818795
# Patient AUC: 0.62770 - Slice AUC: 0.57099
#  Hold out:
# Val loss: 0.66692 - time: 0:00:00.974574
# Patient AUC: 0.68182 - Slice AUC: 0.58402
# Early stopping. Best model is epoch 4
# Val loss: 0.67955, Val auc: 0.62888
# Saving model...
# ### Train ['T1wCE'] on fold 3: ###
# 100%|██████████| 373/373 [00:01<00:00, 296.08it/s]
# Loading dataset: 100%|██████████| 8132/8132 [00:27<00:00, 297.72it/s]
# 100%|██████████| 373/373 [00:01<00:00, 304.79it/s]
# Loading dataset: 100%|██████████| 2034/2034 [00:06<00:00, 294.86it/s]
# 100%|██████████| 93/93 [00:00<00:00, 289.19it/s]
# Loading dataset: 100%|██████████| 2666/2666 [00:09<00:00, 286.17it/s]
# Epoch 1/40:
# Train loss: 0.69079 - time: 0:00:02.798481
#  Validation:
# Val loss: 0.68387 - time: 0:00:00.827820
# Patient AUC: 0.59397 - Slice AUC: 0.55911
#  Hold out:
# Val loss: 0.67295 - time: 0:00:00.969850
# Patient AUC: 0.66651 - Slice AUC: 0.57319
# Val AUC improved from -inf to 0.59397
#
# Epoch 2/40:
# Train loss: 0.68520 - time: 0:00:02.707095
#  Validation:
# Val loss: 0.68101 - time: 0:00:00.833557
# Patient AUC: 0.60790 - Slice AUC: 0.56802
#  Hold out:
# Val loss: 0.67413 - time: 0:00:00.975228
# Patient AUC: 0.67764 - Slice AUC: 0.58480
# Val AUC improved from 0.59397 to 0.60790
#
# Epoch 3/40:
# Train loss: 0.68276 - time: 0:00:02.697724
#  Validation:
# Val loss: 0.68196 - time: 0:00:00.799435
# Patient AUC: 0.60313 - Slice AUC: 0.57518
#  Hold out:
# Val loss: 0.67775 - time: 0:00:00.943769
# Patient AUC: 0.67996 - Slice AUC: 0.57852
#
# Epoch 4/40:
# Train loss: 0.68084 - time: 0:00:02.797603
#  Validation:
# Val loss: 0.67723 - time: 0:00:00.819013
# Patient AUC: 0.61331 - Slice AUC: 0.57657
#  Hold out:
# Val loss: 0.66975 - time: 0:00:00.954292
# Patient AUC: 0.67996 - Slice AUC: 0.59049
# Val AUC improved from 0.60790 to 0.61331
#
# Epoch 5/40:
# Train loss: 0.67713 - time: 0:00:02.730394
#  Validation:
# Val loss: 0.67403 - time: 0:00:00.798581
# Patient AUC: 0.62663 - Slice AUC: 0.58734
#  Hold out:
# Val loss: 0.67406 - time: 0:00:00.980295
# Patient AUC: 0.67301 - Slice AUC: 0.58693
# Val AUC improved from 0.61331 to 0.62663
#
# Epoch 6/40:
# Train loss: 0.67527 - time: 0:00:02.679392
#  Validation:
# Val loss: 0.67371 - time: 0:00:00.819886
# Patient AUC: 0.62627 - Slice AUC: 0.58398
#  Hold out:
# Val loss: 0.67459 - time: 0:00:00.993302
# Patient AUC: 0.66883 - Slice AUC: 0.59104
#
# Epoch 7/40:
# Train loss: 0.67401 - time: 0:00:02.695086
#  Validation:
# Val loss: 0.67251 - time: 0:00:00.846440
# Patient AUC: 0.62876 - Slice AUC: 0.58882
#  Hold out:
# Val loss: 0.68252 - time: 0:00:00.999198
# Patient AUC: 0.61364 - Slice AUC: 0.56492
# Val AUC improved from 0.62663 to 0.62876
#
# Epoch 8/40:
# Train loss: 0.67149 - time: 0:00:02.724546
#  Validation:
# Val loss: 0.67683 - time: 0:00:00.832828
# Patient AUC: 0.63765 - Slice AUC: 0.59146
#  Hold out:
# Val loss: 0.68702 - time: 0:00:00.987547
# Patient AUC: 0.66744 - Slice AUC: 0.56331
# Val AUC improved from 0.62876 to 0.63765
#
# Epoch 9/40:
# Train loss: 0.66793 - time: 0:00:02.698306
#  Validation:
# Val loss: 0.66840 - time: 0:00:00.799048
# Patient AUC: 0.65819 - Slice AUC: 0.60272
#  Hold out:
# Val loss: 0.67941 - time: 0:00:00.963621
# Patient AUC: 0.65399 - Slice AUC: 0.55275
# Val AUC improved from 0.63765 to 0.65819
#
# Epoch 10/40:
# Train loss: 0.66251 - time: 0:00:02.670916
#  Validation:
# Val loss: 0.66312 - time: 0:00:00.834206
# Patient AUC: 0.67566 - Slice AUC: 0.62420
#  Hold out:
# Val loss: 0.68114 - time: 0:00:00.975896
# Patient AUC: 0.65724 - Slice AUC: 0.55246
# Val AUC improved from 0.65819 to 0.67566
#
# Epoch 11/40:
# Train loss: 0.65721 - time: 0:00:02.778346
#  Validation:
# Val loss: 0.66629 - time: 0:00:00.843193
# Patient AUC: 0.68372 - Slice AUC: 0.60847
#  Hold out:
# Val loss: 0.68799 - time: 0:00:00.980172
# Patient AUC: 0.60668 - Slice AUC: 0.52825
# Val AUC improved from 0.67566 to 0.68372
#
# Epoch 12/40:
# Train loss: 0.65101 - time: 0:00:02.866499
#  Validation:
# Val loss: 0.66213 - time: 0:00:00.842155
# Patient AUC: 0.68317 - Slice AUC: 0.62242
#  Hold out:
# Val loss: 0.69806 - time: 0:00:00.998311
# Patient AUC: 0.58302 - Slice AUC: 0.52164
#
# Epoch 13/40:
# Train loss: 0.64408 - time: 0:00:02.771746
#  Validation:
# Val loss: 0.66271 - time: 0:00:00.860613
# Patient AUC: 0.68920 - Slice AUC: 0.62473
#  Hold out:
# Val loss: 0.70357 - time: 0:00:01.003584
# Patient AUC: 0.59416 - Slice AUC: 0.52290
# Val AUC improved from 0.68372 to 0.68920
#
# Epoch 14/40:
# Train loss: 0.64075 - time: 0:00:02.782572
#  Validation:
# Val loss: 0.65675 - time: 0:00:00.830715
# Patient AUC: 0.70516 - Slice AUC: 0.63501
#  Hold out:
# Val loss: 0.71375 - time: 0:00:01.004219
# Patient AUC: 0.60529 - Slice AUC: 0.53677
# Val AUC improved from 0.68920 to 0.70516
#
# Epoch 15/40:
# Train loss: 0.63044 - time: 0:00:02.687320
#  Validation:
# Val loss: 0.66000 - time: 0:00:00.875316
# Patient AUC: 0.71712 - Slice AUC: 0.61665
#  Hold out:
# Val loss: 0.70889 - time: 0:00:00.985971
# Patient AUC: 0.57096 - Slice AUC: 0.51343
# Val AUC improved from 0.70516 to 0.71712
#
# Epoch 16/40:
# Train loss: 0.62236 - time: 0:00:02.741287
#  Validation:
# Val loss: 0.64910 - time: 0:00:00.841498
# Patient AUC: 0.73082 - Slice AUC: 0.63301
#  Hold out:
# Val loss: 0.70139 - time: 0:00:00.982574
# Patient AUC: 0.60575 - Slice AUC: 0.53238
# Val AUC improved from 0.71712 to 0.73082
#
# Epoch 17/40:
# Train loss: 0.60794 - time: 0:00:02.764122
#  Validation:
# Val loss: 0.63967 - time: 0:00:00.847492
# Patient AUC: 0.73962 - Slice AUC: 0.66111
#  Hold out:
# Val loss: 0.72172 - time: 0:00:00.973889
# Patient AUC: 0.60622 - Slice AUC: 0.53666
# Val AUC improved from 0.73082 to 0.73962
#
# Epoch 18/40:
# Train loss: 0.60310 - time: 0:00:02.768866
#  Validation:
# Val loss: 0.64799 - time: 0:00:00.827248
# Patient AUC: 0.75264 - Slice AUC: 0.64694
#  Hold out:
# Val loss: 0.72509 - time: 0:00:00.979602
# Patient AUC: 0.61410 - Slice AUC: 0.53017
# Val AUC improved from 0.73962 to 0.75264
#
# Epoch 19/40:
# Train loss: 0.59341 - time: 0:00:02.698153
#  Validation:
# Val loss: 0.64766 - time: 0:00:00.844857
# Patient AUC: 0.75700 - Slice AUC: 0.65220
#  Hold out:
# Val loss: 0.75167 - time: 0:00:00.979012
# Patient AUC: 0.53803 - Slice AUC: 0.50813
# Val AUC improved from 0.75264 to 0.75700
#
# Epoch 20/40:
# Train loss: 0.58473 - time: 0:00:02.651212
#  Validation:
# Val loss: 0.64254 - time: 0:00:00.811841
# Patient AUC: 0.77908 - Slice AUC: 0.67092
#  Hold out:
# Val loss: 0.77915 - time: 0:00:00.951928
# Patient AUC: 0.58210 - Slice AUC: 0.51462
# Val AUC improved from 0.75700 to 0.77908
#
# Epoch 21/40:
# Train loss: 0.57773 - time: 0:00:02.725107
#  Validation:
# Val loss: 0.63370 - time: 0:00:00.822775
# Patient AUC: 0.78775 - Slice AUC: 0.67613
#  Hold out:
# Val loss: 0.76637 - time: 0:00:00.963884
# Patient AUC: 0.57746 - Slice AUC: 0.51300
# Val AUC improved from 0.77908 to 0.78775
#
# Epoch 22/40:
# Train loss: 0.56610 - time: 0:00:02.716881
#  Validation:
# Val loss: 0.64484 - time: 0:00:00.922170
# Patient AUC: 0.77798 - Slice AUC: 0.67086
#  Hold out:
# Val loss: 0.78494 - time: 0:00:01.075104
# Patient AUC: 0.58442 - Slice AUC: 0.51622
#
# Epoch 23/40:
# Train loss: 0.55960 - time: 0:00:02.798477
#  Validation:
# Val loss: 0.65059 - time: 0:00:00.825428
# Patient AUC: 0.77083 - Slice AUC: 0.66814
#  Hold out:
# Val loss: 0.80529 - time: 0:00:00.987667
# Patient AUC: 0.59323 - Slice AUC: 0.52190
#
# Epoch 24/40:
# Train loss: 0.54483 - time: 0:00:02.712435
#  Validation:
# Val loss: 0.63560 - time: 0:00:00.835717
# Patient AUC: 0.79742 - Slice AUC: 0.67994
#  Hold out:
# Val loss: 0.80480 - time: 0:00:01.026625
# Patient AUC: 0.54545 - Slice AUC: 0.50937
# Val AUC improved from 0.78775 to 0.79742
#
# Epoch 25/40:
# Train loss: 0.54245 - time: 0:00:02.665118
#  Validation:
# Val loss: 0.64436 - time: 0:00:00.819449
# Patient AUC: 0.80642 - Slice AUC: 0.67835
#  Hold out:
# Val loss: 0.81534 - time: 0:00:00.968333
# Patient AUC: 0.57468 - Slice AUC: 0.50997
# Val AUC improved from 0.79742 to 0.80642
#
# Epoch 26/40:
# Train loss: 0.53208 - time: 0:00:02.716423
#  Validation:
# Val loss: 0.64462 - time: 0:00:00.831568
# Patient AUC: 0.79742 - Slice AUC: 0.66992
#  Hold out:
# Val loss: 0.80970 - time: 0:00:00.973903
# Patient AUC: 0.50371 - Slice AUC: 0.50291
#
# Epoch 27/40:
# Train loss: 0.52380 - time: 0:00:02.678026
#  Validation:
# Val loss: 0.63311 - time: 0:00:00.836470
# Patient AUC: 0.76731 - Slice AUC: 0.68266
#  Hold out:
# Val loss: 0.80502 - time: 0:00:00.974834
# Patient AUC: 0.51670 - Slice AUC: 0.50198
#
# Epoch 28/40:
# Train loss: 0.51465 - time: 0:00:02.682007
#  Validation:
# Val loss: 0.65044 - time: 0:00:00.827767
# Patient AUC: 0.81480 - Slice AUC: 0.69873
#  Hold out:
# Val loss: 0.87276 - time: 0:00:00.954206
# Patient AUC: 0.58442 - Slice AUC: 0.51715
# Val AUC improved from 0.80642 to 0.81480
#
# Epoch 29/40:
# Train loss: 0.51016 - time: 0:00:02.674718
#  Validation:
# Val loss: 0.64490 - time: 0:00:00.832912
# Patient AUC: 0.81454 - Slice AUC: 0.70067
#  Hold out:
# Val loss: 0.88885 - time: 0:00:00.992369
# Patient AUC: 0.56262 - Slice AUC: 0.51035
#
# Epoch 30/40:
# Train loss: 0.50968 - time: 0:00:02.702690
#  Validation:
# Val loss: 0.67828 - time: 0:00:00.835649
# Patient AUC: 0.78572 - Slice AUC: 0.69072
#  Hold out:
# Val loss: 0.91496 - time: 0:00:00.987714
# Patient AUC: 0.57421 - Slice AUC: 0.51704
#
# Epoch 31/40:
# Train loss: 0.49246 - time: 0:00:02.766118
#  Validation:
# Val loss: 0.65769 - time: 0:00:00.843344
# Patient AUC: 0.80619 - Slice AUC: 0.69477
#  Hold out:
# Val loss: 0.91737 - time: 0:00:00.984456
# Patient AUC: 0.54360 - Slice AUC: 0.50058
#
# Epoch 32/40:
# Train loss: 0.48370 - time: 0:00:02.718750
#  Validation:
# Val loss: 0.65863 - time: 0:00:00.854965
# Patient AUC: 0.79913 - Slice AUC: 0.68769
#  Hold out:
# Val loss: 0.92382 - time: 0:00:00.986372
# Patient AUC: 0.53664 - Slice AUC: 0.50351
# Early stopping. Best model is epoch 28
# Val loss: 0.65044, Val auc: 0.81480
# Saving model...
# ### Train ['T1wCE'] on fold 4: ###
# 100%|██████████| 373/373 [00:01<00:00, 301.45it/s]
# Loading dataset: 100%|██████████| 8198/8198 [00:27<00:00, 295.49it/s]
# 100%|██████████| 373/373 [00:01<00:00, 312.09it/s]
# Loading dataset: 100%|██████████| 2050/2050 [00:06<00:00, 295.39it/s]
# 100%|██████████| 93/93 [00:00<00:00, 307.30it/s]
# Loading dataset: 100%|██████████| 2584/2584 [00:08<00:00, 300.26it/s]
# Epoch 1/40:
# Train loss: 0.68700 - time: 0:00:02.867749
#  Validation:
# Val loss: 0.68658 - time: 0:00:00.846588
# Patient AUC: 0.56035 - Slice AUC: 0.55673
#  Hold out:
# Val loss: 0.69533 - time: 0:00:00.954969
# Patient AUC: 0.55798 - Slice AUC: 0.53881
# Val AUC improved from -inf to 0.56035
#
# Epoch 2/40:
# Train loss: 0.68101 - time: 0:00:02.666949
#  Validation:
# Val loss: 0.67263 - time: 0:00:00.878240
# Patient AUC: 0.60537 - Slice AUC: 0.57884
#  Hold out:
# Val loss: 0.70718 - time: 0:00:00.945262
# Patient AUC: 0.53479 - Slice AUC: 0.52121
# Val AUC improved from 0.56035 to 0.60537
#
# Epoch 3/40:
# Train loss: 0.67685 - time: 0:00:02.714814
#  Validation:
# Val loss: 0.67334 - time: 0:00:00.856774
# Patient AUC: 0.60842 - Slice AUC: 0.58284
#  Hold out:
# Val loss: 0.70012 - time: 0:00:00.941704
# Patient AUC: 0.53618 - Slice AUC: 0.51920
# Val AUC improved from 0.60537 to 0.60842
#
# Epoch 4/40:
# Train loss: 0.67514 - time: 0:00:02.686106
#  Validation:
# Val loss: 0.67536 - time: 0:00:00.827130
# Patient AUC: 0.61244 - Slice AUC: 0.58067
#  Hold out:
# Val loss: 0.69861 - time: 0:00:00.970361
# Patient AUC: 0.52551 - Slice AUC: 0.51416
# Val AUC improved from 0.60842 to 0.61244
#
# Epoch 5/40:
# Train loss: 0.67197 - time: 0:00:02.703495
#  Validation:
# Val loss: 0.66880 - time: 0:00:00.833141
# Patient AUC: 0.62534 - Slice AUC: 0.60167
#  Hold out:
# Val loss: 0.70124 - time: 0:00:00.948029
# Patient AUC: 0.54221 - Slice AUC: 0.52950
# Val AUC improved from 0.61244 to 0.62534
#
# Epoch 6/40:
# Train loss: 0.66981 - time: 0:00:02.689310
#  Validation:
# Val loss: 0.66899 - time: 0:00:00.831715
# Patient AUC: 0.62582 - Slice AUC: 0.59477
#  Hold out:
# Val loss: 0.71444 - time: 0:00:00.977104
# Patient AUC: 0.54870 - Slice AUC: 0.52570
# Val AUC improved from 0.62534 to 0.62582
#
# Epoch 7/40:
# Train loss: 0.66871 - time: 0:00:02.739202
#  Validation:
# Val loss: 0.67843 - time: 0:00:00.827095
# Patient AUC: 0.63694 - Slice AUC: 0.61089
#  Hold out:
# Val loss: 0.70162 - time: 0:00:00.956427
# Patient AUC: 0.55288 - Slice AUC: 0.52703
# Val AUC improved from 0.62582 to 0.63694
#
# Epoch 8/40:
# Train loss: 0.66755 - time: 0:00:02.719107
#  Validation:
# Val loss: 0.66997 - time: 0:00:00.911815
# Patient AUC: 0.62991 - Slice AUC: 0.59557
#  Hold out:
# Val loss: 0.69432 - time: 0:00:01.031501
# Patient AUC: 0.58210 - Slice AUC: 0.54333
#
# Epoch 9/40:
# Train loss: 0.66287 - time: 0:00:02.896470
#  Validation:
# Val loss: 0.66407 - time: 0:00:00.856530
# Patient AUC: 0.64734 - Slice AUC: 0.60062
#  Hold out:
# Val loss: 0.71902 - time: 0:00:00.934383
# Patient AUC: 0.53850 - Slice AUC: 0.50489
# Val AUC improved from 0.63694 to 0.64734
#
# Epoch 10/40:
# Train loss: 0.65816 - time: 0:00:02.698414
#  Validation:
# Val loss: 0.65621 - time: 0:00:00.838315
# Patient AUC: 0.67009 - Slice AUC: 0.61358
#  Hold out:
# Val loss: 0.72958 - time: 0:00:00.960876
# Patient AUC: 0.52876 - Slice AUC: 0.50304
# Val AUC improved from 0.64734 to 0.67009
#
# Epoch 11/40:
# Train loss: 0.65304 - time: 0:00:02.728168
#  Validation:
# Val loss: 0.65664 - time: 0:00:00.832572
# Patient AUC: 0.67960 - Slice AUC: 0.62539
#  Hold out:
# Val loss: 0.71690 - time: 0:00:00.957215
# Patient AUC: 0.56030 - Slice AUC: 0.51637
# Val AUC improved from 0.67009 to 0.67960
#
# Epoch 12/40:
# Train loss: 0.64575 - time: 0:00:02.690884
#  Validation:
# Val loss: 0.66747 - time: 0:00:00.850058
# Patient AUC: 0.69182 - Slice AUC: 0.61172
#  Hold out:
# Val loss: 0.71655 - time: 0:00:00.965903
# Patient AUC: 0.55473 - Slice AUC: 0.50448
# Val AUC improved from 0.67960 to 0.69182
#
# Epoch 13/40:
# Train loss: 0.64274 - time: 0:00:02.699175
#  Validation:
# Val loss: 0.64836 - time: 0:00:00.833722
# Patient AUC: 0.70046 - Slice AUC: 0.63375
#  Hold out:
# Val loss: 0.72394 - time: 0:00:00.948023
# Patient AUC: 0.58998 - Slice AUC: 0.52445
# Val AUC improved from 0.69182 to 0.70046
#
# Epoch 14/40:
# Train loss: 0.63561 - time: 0:00:02.664300
#  Validation:
# Val loss: 0.64357 - time: 0:00:00.831280
# Patient AUC: 0.70081 - Slice AUC: 0.64456
#  Hold out:
# Val loss: 0.74809 - time: 0:00:00.972088
# Patient AUC: 0.55937 - Slice AUC: 0.51592
# Val AUC improved from 0.70046 to 0.70081
#
# Epoch 15/40:
# Train loss: 0.62887 - time: 0:00:02.658074
#  Validation:
# Val loss: 0.64873 - time: 0:00:00.843244
# Patient AUC: 0.71055 - Slice AUC: 0.64402
#  Hold out:
# Val loss: 0.75169 - time: 0:00:00.958775
# Patient AUC: 0.55473 - Slice AUC: 0.50113
# Val AUC improved from 0.70081 to 0.71055
#
# Epoch 16/40:
# Train loss: 0.61794 - time: 0:00:02.764321
#  Validation:
# Val loss: 0.64132 - time: 0:00:00.827599
# Patient AUC: 0.71814 - Slice AUC: 0.64645
#  Hold out:
# Val loss: 0.77620 - time: 0:00:00.965264
# Patient AUC: 0.54545 - Slice AUC: 0.50564
# Val AUC improved from 0.71055 to 0.71814
#
# Epoch 17/40:
# Train loss: 0.61256 - time: 0:00:02.782467
#  Validation:
# Val loss: 0.64285 - time: 0:00:00.855670
# Patient AUC: 0.73293 - Slice AUC: 0.64835
#  Hold out:
# Val loss: 0.78801 - time: 0:00:00.963449
# Patient AUC: 0.53571 - Slice AUC: 0.49198
# Val AUC improved from 0.71814 to 0.73293
#
# Epoch 18/40:
# Train loss: 0.60646 - time: 0:00:02.659875
#  Validation:
# Val loss: 0.63269 - time: 0:00:00.848998
# Patient AUC: 0.72963 - Slice AUC: 0.66309
#  Hold out:
# Val loss: 0.75114 - time: 0:00:00.961882
# Patient AUC: 0.57050 - Slice AUC: 0.52374
#
# Epoch 19/40:
# Train loss: 0.60327 - time: 0:00:02.693528
#  Validation:
# Val loss: 0.63471 - time: 0:00:00.845021
# Patient AUC: 0.74195 - Slice AUC: 0.65456
#  Hold out:
# Val loss: 0.76810 - time: 0:00:00.936302
# Patient AUC: 0.58117 - Slice AUC: 0.51158
# Val AUC improved from 0.73293 to 0.74195
#
# Epoch 20/40:
# Train loss: 0.59030 - time: 0:00:02.705497
#  Validation:
# Val loss: 0.64144 - time: 0:00:00.840446
# Patient AUC: 0.72503 - Slice AUC: 0.64914
#  Hold out:
# Val loss: 0.78990 - time: 0:00:00.942006
# Patient AUC: 0.55612 - Slice AUC: 0.51807
#
# Epoch 21/40:
# Train loss: 0.58272 - time: 0:00:02.707914
#  Validation:
# Val loss: 0.63990 - time: 0:00:00.857938
# Patient AUC: 0.73900 - Slice AUC: 0.65733
#  Hold out:
# Val loss: 0.81087 - time: 0:00:00.957367
# Patient AUC: 0.58395 - Slice AUC: 0.50936
#
# Epoch 22/40:
# Train loss: 0.57615 - time: 0:00:02.688601
#  Validation:
# Val loss: 0.63294 - time: 0:00:00.857469
# Patient AUC: 0.75160 - Slice AUC: 0.66402
#  Hold out:
# Val loss: 0.81130 - time: 0:00:00.972130
# Patient AUC: 0.56494 - Slice AUC: 0.50395
# Val AUC improved from 0.74195 to 0.75160
#
# Epoch 23/40:
# Train loss: 0.57126 - time: 0:00:02.688583
#  Validation:
# Val loss: 0.63646 - time: 0:00:00.870553
# Patient AUC: 0.74978 - Slice AUC: 0.66368
#  Hold out:
# Val loss: 0.83915 - time: 0:00:00.970846
# Patient AUC: 0.56494 - Slice AUC: 0.50285
#
# Epoch 24/40:
# Train loss: 0.56295 - time: 0:00:02.745698
#  Validation:
# Val loss: 0.63267 - time: 0:00:00.835607
# Patient AUC: 0.75935 - Slice AUC: 0.65344
#  Hold out:
# Val loss: 0.83519 - time: 0:00:00.963114
# Patient AUC: 0.53479 - Slice AUC: 0.49972
# Val AUC improved from 0.75160 to 0.75935
#
# Epoch 25/40:
# Train loss: 0.55721 - time: 0:00:02.755291
#  Validation:
# Val loss: 0.64067 - time: 0:00:00.844238
# Patient AUC: 0.76443 - Slice AUC: 0.66673
#  Hold out:
# Val loss: 0.87781 - time: 0:00:00.972902
# Patient AUC: 0.55519 - Slice AUC: 0.49835
# Val AUC improved from 0.75935 to 0.76443
#
# Epoch 26/40:
# Train loss: 0.54819 - time: 0:00:02.738397
#  Validation:
# Val loss: 0.63919 - time: 0:00:00.848045
# Patient AUC: 0.77119 - Slice AUC: 0.66387
#  Hold out:
# Val loss: 0.87275 - time: 0:00:00.971404
# Patient AUC: 0.55566 - Slice AUC: 0.49975
# Val AUC improved from 0.76443 to 0.77119
#
# Epoch 27/40:
# Train loss: 0.54341 - time: 0:00:02.750350
#  Validation:
# Val loss: 0.63636 - time: 0:00:00.825681
# Patient AUC: 0.76896 - Slice AUC: 0.65888
#  Hold out:
# Val loss: 0.83686 - time: 0:00:00.953593
# Patient AUC: 0.54638 - Slice AUC: 0.50216
#
# Epoch 28/40:
# Train loss: 0.53968 - time: 0:00:02.706004
#  Validation:
# Val loss: 0.64044 - time: 0:00:00.836326
# Patient AUC: 0.76467 - Slice AUC: 0.64898
#  Hold out:
# Val loss: 0.85731 - time: 0:00:01.211991
# Patient AUC: 0.51252 - Slice AUC: 0.48827
#
# Epoch 29/40:
# Train loss: 0.53171 - time: 0:00:02.802727
#  Validation:
# Val loss: 0.65562 - time: 0:00:00.884813
# Patient AUC: 0.76083 - Slice AUC: 0.64958
#  Hold out:
# Val loss: 0.88405 - time: 0:00:00.967341
# Patient AUC: 0.56122 - Slice AUC: 0.50147
#
# Epoch 30/40:
# Train loss: 0.52502 - time: 0:00:02.720298
#  Validation:
# Val loss: 0.64651 - time: 0:00:00.838691
# Patient AUC: 0.76961 - Slice AUC: 0.66258
#  Hold out:
# Val loss: 0.88403 - time: 0:00:00.969797
# Patient AUC: 0.55288 - Slice AUC: 0.50964
# Early stopping. Best model is epoch 26
# Val loss: 0.63919, Val auc: 0.77119
# Saving model...

# %% [markdown]
# Evaluate

# %%
metrics = []
results = []
find_weight = lambda x: [w for w in os.listdir() if x in w][0]
weights_paths = [f'{"_".join(mri_types)}_fold{fold}' for fold in range(n_folds)]
weights_paths = [find_weight(x) for x in weights_paths]
for fold, weights_path in enumerate(weights_paths):
    print(f'### Evaluate {mri_types} on fold {fold}: ###')
    _, _, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                     fold=fold,
                                                     cache_rate=0.0)
    pipeline.load_model(weights_path)
    val_metric, val_result = pipeline.evaluate(val_holdout_ds, batch_size=batch_size, verbose=True)
    metrics.append(val_metric)
    results.append(val_result)
results = pd.concat(results, ignore_index=True)
mean_auc = np.mean(metrics)
oof_auc = roc_auc_score(results['label'], results['probability'])
print('---')
print(f'{mri_types} holdout result:')
print(' Mean AUC: {:.5f}'.format(mean_auc))
print(' Out-of-fold AUC: {:.5f}'.format(oof_auc))
print('---')
# Out:
# ### Evaluate ['T1wCE'] on fold 0: ###
# 100%|██████████| 372/372 [00:01<00:00, 286.85it/s]
# 100%|██████████| 372/372 [00:01<00:00, 223.14it/s]
# 100%|██████████| 94/94 [00:00<00:00, 292.32it/s]
#  Hold out:
# Val loss: 1.16614 - time: 0:00:05.415222
# Patient AUC: 0.44136 - Slice AUC: 0.46616
# ### Evaluate ['T1wCE'] on fold 1: ###
# 100%|██████████| 373/373 [00:01<00:00, 284.12it/s]
# 100%|██████████| 373/373 [00:01<00:00, 297.83it/s]
# 100%|██████████| 93/93 [00:00<00:00, 301.64it/s]
#  Hold out:
# Val loss: 0.78218 - time: 0:00:05.008850
# Patient AUC: 0.59647 - Slice AUC: 0.53258
# ### Evaluate ['T1wCE'] on fold 2: ###
# 100%|██████████| 373/373 [00:01<00:00, 298.51it/s]
# 100%|██████████| 373/373 [00:01<00:00, 313.40it/s]
# 100%|██████████| 93/93 [00:00<00:00, 291.29it/s]
#  Hold out:
# Val loss: 0.66818 - time: 0:00:05.598575
# Patient AUC: 0.69063 - Slice AUC: 0.60524
# ### Evaluate ['T1wCE'] on fold 3: ###
# 100%|██████████| 373/373 [00:01<00:00, 293.50it/s]
# 100%|██████████| 373/373 [00:01<00:00, 308.08it/s]
# 100%|██████████| 93/93 [00:00<00:00, 311.77it/s]
#  Hold out:
# Val loss: 0.87276 - time: 0:00:05.563796
# Patient AUC: 0.58442 - Slice AUC: 0.51715
# ### Evaluate ['T1wCE'] on fold 4: ###
# 100%|██████████| 373/373 [00:01<00:00, 293.79it/s]
# 100%|██████████| 373/373 [00:01<00:00, 317.84it/s]
# 100%|██████████| 93/93 [00:00<00:00, 310.52it/s]
#  Hold out:
# Val loss: 0.87275 - time: 0:00:05.222409
# Patient AUC: 0.55566 - Slice AUC: 0.49975
# ---
# ['T1wCE'] holdout result:
#  Mean AUC: 0.57371
#  Out-of-fold AUC: 0.55820
# ---

# %% [markdown]
# submission

# %%
test_results = []
for fold, weights_path in enumerate(weights_paths):
    print(f'### Inference {mri_types} on fold {fold}: ###')
    test_ds = pipeline.prepare_test_dataset(mri_types=mri_types, cache_rate=0.0)
    pipeline.load_model(weights_path)
    test_result = pipeline.predict(test_ds, batch_size=batch_size, verbose=True)
    test_results.append(test_result)
# Out:
# ### Inference ['T1wCE'] on fold 0: ###
# 100%|██████████| 585/585 [00:07<00:00, 75.77it/s]
# Elapsed time: 0:00:50.170949
# ### Inference ['T1wCE'] on fold 1: ###
# 100%|██████████| 585/585 [00:01<00:00, 369.05it/s]
# Elapsed time: 0:00:30.761955
# ### Inference ['T1wCE'] on fold 2: ###
# 100%|██████████| 585/585 [00:01<00:00, 361.37it/s]
# Elapsed time: 0:00:31.838027
# ### Inference ['T1wCE'] on fold 3: ###
# 100%|██████████| 585/585 [00:01<00:00, 368.84it/s]
# Elapsed time: 0:00:31.019870
# ### Inference ['T1wCE'] on fold 4: ###
# 100%|██████████| 585/585 [00:01<00:00, 361.12it/s]
# Elapsed time: 0:00:31.302674

# %%
prediction = pd.concat([x.set_index('BraTS21ID') for x in test_results], axis=1).mean(axis=1)
prediction = pd.DataFrame(prediction, columns=['MGMT_value']).reset_index()
# prediction.to_csv('submission_T1wCE.csv',index=False)

# %%
prediction
# Out:
#      BraTS21ID  MGMT_value
# 0            0    0.735987
# 1            2    0.727254
# 2            3    0.775826
# 3            5    0.722720
# 4            6    0.716705
# ..         ...         ...
# 580       1005    0.513890
# 581       1007    0.356261
# 582       1008    0.536520
# 583       1009    0.493061
# 584       1010    0.438132
#
# [585 rows x 2 columns]

# %%
test_df
# Out:
#      BraTS21ID  MGMT_value
# 0          107           1
# 1          753           0
# 2          303           1
# 3          106           1
# 4          171           1
# ..         ...         ...
# 112        703           0
# 113         21           0
# 114        444           0
# 115         95           0
# 116        640           1
#
# [117 rows x 2 columns]

# %%
result = pd.merge(prediction, test_df, on='BraTS21ID', how='right')

# %%
result
# Out:
#      BraTS21ID  MGMT_value_x  MGMT_value_y
# 0          107      0.397917             1
# 1          753      0.547810             0
# 2          303      0.492362             1
# 3          106      0.279580             1
# 4          171      0.473340             1
# ..         ...           ...           ...
# 112        703      0.614482             0
# 113         21      0.595206             0
# 114        444      0.558625             0
# 115         95      0.695518             0
# 116        640      0.602103             1
#
# [117 rows x 3 columns]

# %%
def get_confusion_matrix(result3, threshold=0.5):

    confusion_matrix = [[0, 0], [0, 0]]

#     for i in range(len(result3)):
#         threshold = 1 if result3.loc[i, "MGMT_value_x"] > threshold else 0
#         confusion_matrix[result3.loc[i, "MGMT_value_y"]][threshold] += 1
        
    for idx, data in result3.iterrows():
        tmp = 1 if data.MGMT_value_x > threshold else 0
        confusion_matrix[int(data.MGMT_value_y)][tmp] += 1

    return confusion_matrix

def get_acc_recall(arr):
    acc = sum((arr[0][0], arr[1][1]))/sum((sum(arr[0]), sum(arr[1])))
    recall = arr[1][1] / sum(arr[1])
    print(f"Acc: {acc} \t Recall: {recall}")

# %%
arr = get_confusion_matrix(result)
print(arr)
get_acc_recall(arr)
# Out:
# [[6, 50], [14, 47]]
# Acc: 0.452991452991453 	 Recall: 0.7704918032786885
