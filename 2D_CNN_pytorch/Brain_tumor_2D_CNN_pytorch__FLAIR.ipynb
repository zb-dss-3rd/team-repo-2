# %%
# !nvidia-smi
# Out:
# Sun Oct 16 07:27:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install monai
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting monai
#   Downloading monai-1.0.0-202209161346-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from monai) (1.21.6)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from monai) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7->monai) (4.1.1)
# Installing collected packages: monai
# Successfully installed monai-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 4.2 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.0

# %%
import sys
import os
import cv2
import glob
import pydicom
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import time
import datetime
from dataclasses import dataclass, field
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score
from copy import deepcopy

from monai.data import CacheDataset, DataLoader
from monai.transforms import *

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(42)

class AverageMeter:
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
DATA_DIR = '/content/drive/MyDrive/PROJECT_kaggle'
MRI_TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]

# %%
TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]
excluded_imgaes = [109, 123, 709]

DATA_DIR_path = '/content/drive/MyDrive/PROJECT_kaggle'

train_df = pd.read_csv(DATA_DIR_path + "/train_df.csv")
test_df = pd.read_csv(DATA_DIR_path + '/test_df.csv')
train_df = train_df[~train_df.BraTS21ID.isin(excluded_imgaes)]

def load_dicom(path, size = 224):
    ''' 
    Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, then rescales to 0 and 255
    
    Note super sure if this kind of scaling is appropriate, but everyone seems to do it. 
    '''
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if np.max(data) != 0:
        data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return cv2.resize(data, (size, size))

def get_all_image_paths(brats21id, image_type, folder='train'): 
    '''
    Returns an arry of all the images of a particular type for a particular patient ID
    '''
    assert(image_type in TYPES)
    
    patient_path = os.path.join(
        DATA_DIR_path + "/%s/" % folder, 
        str(brats21id).zfill(5),
    )

    paths = sorted(
        glob.glob(os.path.join(patient_path, image_type, "*")), 
        key=lambda x: int(x[:-4].split("-")[-1]),
    )
    
    num_images = len(paths)
    
    start = int(num_images * 0.25)
    end = int(num_images * 0.75)

    interval = 3
    
    if num_images < 10: 
        interval = 1
    
    return np.array(paths[start:end:interval])

def get_all_images(brats21id, image_type, folder='train', size=225):
    return [load_dicom(path, size) for path in get_all_image_paths(brats21id, image_type, folder)]
IMAGE_SIZE = 128

def get_all_data_for_train(image_type):
    global train_df
    
    X = []
    y = []
    train_ids = []

    for i in tqdm(train_df.index):
        x = train_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        label = x['MGMT_value']

        X += images
        y += [label] * len(images)
        train_ids += [int(x['BraTS21ID'])] * len(images)
        assert(len(X) == len(y))
    return np.array(X), np.array(y), np.array(train_ids)

def get_all_data_for_test(image_type):
    global train_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

def get_all_data_for_val(image_type):
    global test_df
    
    X = []
    test_ids = []

    for i in tqdm(test_df.index):
        x = test_df.loc[i]
        images = get_all_images(int(x['BraTS21ID']), image_type, 'train', IMAGE_SIZE)
        X += images
        test_ids += [int(x['BraTS21ID'])] * len(images)

    return np.array(X), np.array(test_ids)

X, y, trainidt = get_all_data_for_train('FLAIR')
X_test, testidt = get_all_data_for_test('FLAIR')
X.shape, y.shape, trainidt.shape
# Out:
# 100%|██████████| 466/466 [45:00<00:00,  5.80s/it]
# 100%|██████████| 117/117 [10:56<00:00,  5.61s/it]
# ((10011, 128, 128), (10011,), (10011,))

# %%
train_df
# Out:
#      BraTS21ID  MGMT_value
# 0          185           1
# 1          816           1
# 2          707           1
# 3          683           0
# 4            6           1
# ..         ...         ...
# 463        356           0
# 464         89           1
# 465        217           0
# 466        834           0
# 467        708           1
#
# [466 rows x 2 columns]

# %%
test_df
# Out:
#      BraTS21ID  MGMT_value
# 0          107           1
# 1          753           0
# 2          303           1
# 3          106           1
# 4          171           1
# ..         ...         ...
# 112        703           0
# 113         21           0
# 114        444           0
# 115         95           0
# 116        640           1
#
# [117 rows x 2 columns]

# %%
X_train, X_valid, y_train, y_valid, trainidt_train, trainidt_valid = train_test_split(X, y, trainidt, test_size=0.2, random_state=40)

split = int(X.shape[0] * 0.8)
 
X_train = torch.Tensor(X_train)
X_valid = torch.Tensor(X_valid)

X_train = torch.unsqueeze(X_train, -1).size()
X_valid = torch.unsqueeze(X_valid, -1).size()

y_train = torch.Tensor(y_train)
y_valid = torch.Tensor(y_valid)


# X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, trainidt_train.shape, trainidt_valid.shape
X_train, y_train, X_valid, y_valid, trainidt_train, trainidt_valid
# Out:
# (torch.Size([8008, 128, 128, 1]),
#  tensor([0., 1., 1.,  ..., 0., 0., 1.]),
#  torch.Size([2003, 128, 128, 1]),
#  tensor([1., 1., 0.,  ..., 0., 1., 1.]),
#  array([414,  33, 661, ..., 563, 477, 661]),
#  array([ 89, 607, 392, ..., 589, 552,  28]))

# %% [markdown]
# Dataset

# %%
class BrainTumorDataset(CacheDataset):
    def __init__(self, root_dir, patient_ids, mri_types, annotations, section, *args, **kwargs):
        self.root_dir = root_dir
        self.patient_ids = patient_ids
        self.mri_types = mri_types
        self.annotations = annotations
        data = self.get_data()
        if section is not None:
            train_data, val_data = train_test_split(data, test_size=0.2, random_state=13)
            data = train_data if section=='train' else val_data
        super(BrainTumorDataset, self).__init__(data, *args, **kwargs)
    
    def get_data(self):
        data = []
        for patient_id in tqdm(self.patient_ids):
            if self.annotations is not None:
                label = self.annotations[self.annotations['BraTS21ID'] 
                                         == int(patient_id)]['MGMT_value'].item()
            else:
                label = 0 # dummy value
            for slice_path in self.get_patient_slice_paths(patient_id):
                data.append({
                    'image': slice_path,
                    'label': label,
                    'patient_id': patient_id
                })
        return data
    
    def get_patient_slice_paths(self, patient_id):
        '''
        Returns an array of all the images of a particular type for a particular patient ID
        '''
        assert(set(self.mri_types) <= set(MRI_TYPES))
        patient_path = os.path.join(self.root_dir, str(patient_id).zfill(5))
        patient_slice_paths = []
        for mri_type in self.mri_types:
            paths = sorted(
                glob.glob(os.path.join(patient_path, mri_type, "*.dcm")), 
                key=lambda x: (x[:-4].split("-")[-1]), # 괄호 앞에 int제거
            )

            num_images = len(paths)
            start = int(num_images * 0.25)
            end = int(num_images * 0.75)

            interval = 3
            if num_images < 10: 
                interval = 1
            patient_slice_paths.extend(paths[start:end:interval])
        return patient_slice_paths
    
class LoadDicomd(MapTransform):
    def __init__(self, img_size, *args, **kwargs):
        self.img_size = img_size
        super(LoadDicomd, self).__init__(*args, **kwargs)
    
    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            d[key] = self.load_dicom(d[key])
        return d

    def load_dicom(self, path):
        ''' 
        Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, 
        then rescales to 0 and 255
        '''
        dicom = pydicom.read_file(path)
        data = dicom.pixel_array
        if np.max(data) != 0:
            data = data / np.max(data)
        data = (data * 255).astype(np.uint8)
        data = cv2.resize(data, (self.img_size, self.img_size)) / 255
        return np.expand_dims(data, axis=0)

# %% [markdown]
# Model

# %%
class Simple2dCNN(nn.Module):
    def __init__(self, 
                 input_channels=1, 
                 n_classes=2, 
                 img_size=32, 
                 conv1_filters=128,
                 conv2_filters=64,
                 dropout_prob=0.1,
                 fc1_units=48):
        super(Simple2dCNN, self).__init__()
        
        self.relu = nn.ReLU()
        
        self.conv1 = nn.Conv2d(input_channels, conv1_filters, 4)
        self.maxpool1 = nn.MaxPool2d(2)
        
        self.conv2 = nn.Conv2d(conv1_filters, conv2_filters, 2)
        self.maxpool2 = nn.MaxPool2d(1)
        
        self.dropout = nn.Dropout(dropout_prob)
        last_feature_map_size = (img_size - 3) // 2 - 1
        self.fc1 = nn.Linear(conv2_filters * last_feature_map_size**2, fc1_units)
        self.fc2 = nn.Linear(fc1_units, n_classes)

    def forward(self, x):
        # (None, 1, 32, 32)
        x = self.relu(self.conv1(x)) # (None, 128, 29, 29)
        x = self.maxpool1(x) # (None, 128, 14, 14)
        
        x = self.relu(self.conv2(x)) # (None, 64, 13, 13)
        x = self.maxpool2(x) # (None, 64, 13, 13)
        
        x = self.dropout(x)
        x = x.view(x.size(0), -1) # (None, 64 * 13 * 13)
        x = self.relu(self.fc1(x)) # (None, 48)
        x = self.fc2(x) # (None, 2)
        return x

# %% [markdown]
# Pipeline

# %%
@dataclass
class Config:
    train_dir: str = os.path.join(DATA_DIR_path, 'train')
    test_dir: str = os.path.join(DATA_DIR_path, 'train')
    annotation_path: str = os.path.join(DATA_DIR_path, 'train_df.csv')
    n_classes: int = 2
    img_size: int = 32
    n_workers: int = 4
    early_stopping_rounds: int = 3
    n_folds: int = 5
        
        
class Pipeline:
    def __init__(self, config):
        self.args = config
        self.device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
        self.annotations = None
        self.model = None
        self.load_model()
        # transforms
        self.preaugment_transform = [
            LoadDicomd(keys="image", img_size=self.args.img_size),
        ]
        self.augment_transform = [] # todo: add some augmentations
        self.postaugment_transform = [
            ToTensord(keys="image", dtype=torch.float),
            ToTensord(keys="label", dtype=torch.int64),
        ]
        
    def load_annotations(self):
        self.annotations = pd.read_csv(self.args.annotation_path)
        # exclude 3 cases
        self.annotations = self.annotations[~self.annotations['BraTS21ID'].isin([109, 123, 709])]
        self.annotations = self.annotations.reset_index(drop=True)
        skf = StratifiedKFold(n_splits=self.args.n_folds, shuffle=True, random_state=42)
        # split by patient, stratify based on target value
        folds = skf.split(self.annotations['BraTS21ID'].values, self.annotations['MGMT_value'].values)
        for i, (train_indices, val_indices) in enumerate(folds):
            self.annotations.loc[val_indices, 'fold'] = i
        self.annotations['fold'] = self.annotations['fold'].astype(int)
    
    def load_model(self, weights_path=None):
        self.model = Simple2dCNN(input_channels=1, 
                                 n_classes=self.args.n_classes,
                                 img_size=self.args.img_size).to(self.device)
        if weights_path:
            weights = torch.load(weights_path, map_location=self.device)
            self.model.load_state_dict(weights)
        
    def prepare_datasets(self, mri_types, fold, cache_rate):
        """
        Data format:
        {
            'image': torch tensor (batch_size, 1, 32, 32),
            'label': torch tensor (batch_size, )
            'patient_id'
        }
        Output: torch tensor (batch_size, 2)
        """
        train_transform = Compose(
            self.preaugment_transform +
            self.augment_transform +
            self.postaugment_transform
        )
        val_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        
        train_ids = self.annotations[self.annotations['fold']!=fold]['BraTS21ID'].values.tolist()
        val_holdout_ids = self.annotations[self.annotations['fold']==fold]['BraTS21ID'].values.tolist()
        
        train_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                     patient_ids=train_ids, 
                                     mri_types=mri_types,  
                                     annotations=self.annotations,
                                     transform=train_transform,
                                     section='train',
                                     cache_rate=cache_rate,
                                     num_workers=self.args.n_workers)
        val_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                   patient_ids=train_ids, 
                                   mri_types=mri_types,  
                                   annotations=self.annotations,
                                   transform=val_transform,
                                   section='val',
                                   cache_rate=cache_rate,
                                   num_workers=self.args.n_workers)
        val_holdout_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                           patient_ids=val_holdout_ids, 
                                           mri_types=mri_types, 
                                           annotations=self.annotations, 
                                           transform=val_transform,
                                           section=None,
                                           cache_rate=cache_rate,
                                           num_workers=self.args.n_workers)
        return train_ds, val_ds, val_holdout_ds
    
    def prepare_test_dataset(self, mri_types, cache_rate):
        test_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        test_ids = [int(patient_id) for patient_id in os.listdir(self.args.test_dir)]
        test_ids = sorted(test_ids, key=lambda x: int(x))
        test_ds = BrainTumorDataset(root_dir=self.args.test_dir, 
                                    patient_ids=test_ids, 
                                    mri_types=mri_types, 
                                    annotations=None, 
                                    transform=test_transform,
                                    section=None,
                                    cache_rate=cache_rate,
                                    num_workers=self.args.n_workers)
        return test_ds
    
    def train_epoch(self, loader, loss_function, optimizer, verbose):
        self.model.train()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        for step, batch_data in enumerate(loader):
            inputs, labels = (
                batch_data["image"].to(self.device), # (None, 1, 32, 32)
                batch_data["label"].to(self.device), # (None, )
            )
            batch_size = inputs.size(0)
            # back propagation
            optimizer.zero_grad()
            outputs = self.model(inputs) # (None, 2)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            # update stats
            summary_loss.update(loss.item(), batch_size)
            if verbose:
                print('Train step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                              summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Train loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        return summary_loss.avg
    
    def evaluate_epoch(self, loader, loss_function, verbose):
        self.model.eval()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        labels_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, labels, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["label"].to(self.device), # (None, )
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # back propagation
                outputs = self.model(inputs) # (None, 2)
                loss = loss_function(outputs, labels)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                labels_all.extend(labels.tolist())
                patient_ids_all.extend(patient_ids)
                
                summary_loss.update(loss.item(), batch_size)
                if verbose:
                    print('Val step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                                summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Val loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
            'label': labels_all
        }
        result = pd.DataFrame(result)
        slice_auc = roc_auc_score(result['label'], result['probability'])
        result = result.groupby("BraTS21ID", as_index=False).mean()
        patient_auc = roc_auc_score(result['label'], result['probability'])
        print('Patient AUC: {:.5f} - Slice AUC: {:.5f}'.format(patient_auc, slice_auc))
        
        return summary_loss.avg, patient_auc, result
    
    def infer_epoch(self, loader, verbose):
        self.model.eval()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # forward
                outputs = self.model(inputs) # (None, 2)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                patient_ids_all.extend(patient_ids)
                if verbose:
                    print('Infer step {}/{}'.format(step + 1, n), end='\r')
        
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
        }
        result = pd.DataFrame(result)
        result = result.groupby("BraTS21ID", as_index=False).mean()
        
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Elapsed time: {}'.format(elapsed_time))
        
        return result
    
    def fit(self, train_ds, val_ds, val_holdout_ds, batch_size, epochs, lr, model_name, verbose):
        train_loader = DataLoader(train_ds, 
                                  batch_size=batch_size, 
                                  shuffle=True,
                                  num_workers=self.args.n_workers)
        val_loader = DataLoader(val_ds, 
                                batch_size=batch_size, 
                                shuffle=False,
                                num_workers=self.args.n_workers)
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        
        current_metric = -np.inf
        current_loss = np.inf
        current_epoch = 1
        current_state_dict = None
        save_path = '{}_imgsize{}_valloss{:.3f}_valauc{:.3f}.pth'
        for epoch in range(1, epochs + 1):
            print('\nEpoch {}/{}:'.format(epoch, epochs))
            train_loss = self.train_epoch(train_loader, loss_function, optimizer, verbose)
            print(' Validation:')
            val_loss, val_metric, _ = self.evaluate_epoch(val_loader, loss_function, verbose)
            print(' Hold out:')
            val_holdout_loss, val_holdout_metric, _ = self.evaluate_epoch(val_holdout_loader, 
                                                                          loss_function, 
                                                                          verbose)
            
#             if val_loss < current_loss:
            if val_metric > current_metric:
                print('Val AUC improved from {:.5f} to {:.5f}'.format(current_metric, val_metric))
                current_metric = val_metric
                current_loss = val_loss
                current_epoch = epoch
                current_state_dict = deepcopy(self.model.state_dict())
                
            elif (epoch - current_epoch) > self.args.early_stopping_rounds:
                print('Early stopping. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                break
            if epoch == epochs:
                print('Finished training. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                
    def evaluate(self, val_holdout_ds, batch_size, verbose):
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        print(' Hold out:')
        _, val_holdout_metric, val_holdout_result = self.evaluate_epoch(val_holdout_loader, 
                                                                        loss_function, 
                                                                        verbose)
        return val_holdout_metric, val_holdout_result
    
    def predict(self, test_ds, batch_size, verbose):
        test_loader = DataLoader(test_ds, 
                                 batch_size=batch_size, 
                                 shuffle=False,
                                 num_workers=self.args.n_workers)
        test_result = self.infer_epoch(test_loader, verbose)
        return test_result

# %%
mri_types = ['FLAIR']
img_size = 16 #32
batch_size = 32
n_workers = 4
early_stopping_rounds = 3
n_folds = 5
epochs = 40 #50
lr = 1e-3

# %%
args = Config(img_size=img_size, 
              n_workers=n_workers, 
              early_stopping_rounds=early_stopping_rounds,
              n_folds=n_folds)
pipeline = Pipeline(args)

# %% [markdown]
# Train

# %%
pipeline.load_annotations()
for fold in range(n_folds):
    print(f'### Train {mri_types} on fold {fold}: ###')
    train_ds, val_ds, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                                 fold=fold,
                                                                 cache_rate=1.0)
    pipeline.load_model()
    pipeline.fit(train_ds, val_ds, val_holdout_ds,
                 batch_size=batch_size, epochs=epochs, lr=lr, 
                 model_name=f'{"_".join(mri_types)}_fold{fold}',
                 verbose=True)
# Out:
# ### Train ['FLAIR'] on fold 0: ###
# 100%|██████████| 372/372 [00:03<00:00, 100.95it/s]
# Loading dataset: 100%|██████████| 6239/6239 [05:20<00:00, 19.49it/s]
# 100%|██████████| 372/372 [00:01<00:00, 362.96it/s]
# Loading dataset: 100%|██████████| 1560/1560 [01:20<00:00, 19.46it/s]
# 100%|██████████| 94/94 [00:00<00:00, 127.01it/s]
# Loading dataset: 100%|██████████| 2212/2212 [01:29<00:00, 24.63it/s]
# Epoch 1/40:
# Train loss: 0.64300 - time: 0:00:09.466342
#  Validation:
# Val loss: 0.62830 - time: 0:00:00.623816
# Patient AUC: 0.65642 - Slice AUC: 0.62521
#  Hold out:
# Val loss: 0.76457 - time: 0:00:00.807568
# Patient AUC: 0.43136 - Slice AUC: 0.52241
# Val AUC improved from -inf to 0.65642
#
# Epoch 2/40:
# Train loss: 0.63502 - time: 0:00:02.025410
#  Validation:
# Val loss: 0.62654 - time: 0:00:00.632114
# Patient AUC: 0.66169 - Slice AUC: 0.64499
#  Hold out:
# Val loss: 0.73343 - time: 0:00:00.783940
# Patient AUC: 0.43136 - Slice AUC: 0.53915
# Val AUC improved from 0.65642 to 0.66169
#
# Epoch 3/40:
# Train loss: 0.62448 - time: 0:00:02.114524
#  Validation:
# Val loss: 0.62195 - time: 0:00:00.642326
# Patient AUC: 0.67001 - Slice AUC: 0.64132
#  Hold out:
# Val loss: 0.72422 - time: 0:00:00.827069
# Patient AUC: 0.43409 - Slice AUC: 0.54427
# Val AUC improved from 0.66169 to 0.67001
#
# Epoch 4/40:
# Train loss: 0.61476 - time: 0:00:02.086230
#  Validation:
# Val loss: 0.61972 - time: 0:00:00.642673
# Patient AUC: 0.65423 - Slice AUC: 0.64043
#  Hold out:
# Val loss: 0.78908 - time: 0:00:00.791045
# Patient AUC: 0.42955 - Slice AUC: 0.49869
#
# Epoch 5/40:
# Train loss: 0.60355 - time: 0:00:02.020298
#  Validation:
# Val loss: 0.60903 - time: 0:00:00.615033
# Patient AUC: 0.68212 - Slice AUC: 0.65972
#  Hold out:
# Val loss: 0.80965 - time: 0:00:00.790200
# Patient AUC: 0.38682 - Slice AUC: 0.48562
# Val AUC improved from 0.67001 to 0.68212
#
# Epoch 6/40:
# Train loss: 0.59589 - time: 0:00:02.041928
#  Validation:
# Val loss: 0.61252 - time: 0:00:00.613258
# Patient AUC: 0.69615 - Slice AUC: 0.66930
#  Hold out:
# Val loss: 0.84155 - time: 0:00:00.780094
# Patient AUC: 0.39182 - Slice AUC: 0.49174
# Val AUC improved from 0.68212 to 0.69615
#
# Epoch 7/40:
# Train loss: 0.58497 - time: 0:00:02.070976
#  Validation:
# Val loss: 0.60078 - time: 0:00:00.623849
# Patient AUC: 0.70287 - Slice AUC: 0.67334
#  Hold out:
# Val loss: 0.80801 - time: 0:00:00.791327
# Patient AUC: 0.39500 - Slice AUC: 0.48808
# Val AUC improved from 0.69615 to 0.70287
#
# Epoch 8/40:
# Train loss: 0.57762 - time: 0:00:02.085247
#  Validation:
# Val loss: 0.60664 - time: 0:00:00.610450
# Patient AUC: 0.71814 - Slice AUC: 0.68261
#  Hold out:
# Val loss: 0.86706 - time: 0:00:00.903220
# Patient AUC: 0.39773 - Slice AUC: 0.50108
# Val AUC improved from 0.70287 to 0.71814
#
# Epoch 9/40:
# Train loss: 0.56625 - time: 0:00:02.142777
#  Validation:
# Val loss: 0.60824 - time: 0:00:00.658213
# Patient AUC: 0.71817 - Slice AUC: 0.67836
#  Hold out:
# Val loss: 0.85701 - time: 0:00:00.820721
# Patient AUC: 0.40409 - Slice AUC: 0.51591
# Val AUC improved from 0.71814 to 0.71817
#
# Epoch 10/40:
# Train loss: 0.55722 - time: 0:00:02.031406
#  Validation:
# Val loss: 0.59474 - time: 0:00:00.645432
# Patient AUC: 0.72917 - Slice AUC: 0.68023
#  Hold out:
# Val loss: 0.80294 - time: 0:00:00.782147
# Patient AUC: 0.39545 - Slice AUC: 0.48501
# Val AUC improved from 0.71817 to 0.72917
#
# Epoch 11/40:
# Train loss: 0.54574 - time: 0:00:02.079515
#  Validation:
# Val loss: 0.58746 - time: 0:00:00.654646
# Patient AUC: 0.73793 - Slice AUC: 0.69985
#  Hold out:
# Val loss: 0.86480 - time: 0:00:00.817332
# Patient AUC: 0.40773 - Slice AUC: 0.47664
# Val AUC improved from 0.72917 to 0.73793
#
# Epoch 12/40:
# Train loss: 0.53397 - time: 0:00:02.063799
#  Validation:
# Val loss: 0.58761 - time: 0:00:00.647630
# Patient AUC: 0.74157 - Slice AUC: 0.70202
#  Hold out:
# Val loss: 0.86093 - time: 0:00:00.795713
# Patient AUC: 0.41136 - Slice AUC: 0.46295
# Val AUC improved from 0.73793 to 0.74157
#
# Epoch 13/40:
# Train loss: 0.51767 - time: 0:00:02.036539
#  Validation:
# Val loss: 0.58759 - time: 0:00:00.634790
# Patient AUC: 0.74202 - Slice AUC: 0.71016
#  Hold out:
# Val loss: 0.90357 - time: 0:00:00.792631
# Patient AUC: 0.39136 - Slice AUC: 0.47251
# Val AUC improved from 0.74157 to 0.74202
#
# Epoch 14/40:
# Train loss: 0.51205 - time: 0:00:02.054023
#  Validation:
# Val loss: 0.59180 - time: 0:00:00.622852
# Patient AUC: 0.74075 - Slice AUC: 0.70442
#  Hold out:
# Val loss: 0.94197 - time: 0:00:00.819908
# Patient AUC: 0.44045 - Slice AUC: 0.48696
#
# Epoch 15/40:
# Train loss: 0.49700 - time: 0:00:02.095622
#  Validation:
# Val loss: 0.60035 - time: 0:00:00.665253
# Patient AUC: 0.74086 - Slice AUC: 0.68425
#  Hold out:
# Val loss: 0.91612 - time: 0:00:00.792701
# Patient AUC: 0.39091 - Slice AUC: 0.45734
#
# Epoch 16/40:
# Train loss: 0.48512 - time: 0:00:02.067218
#  Validation:
# Val loss: 0.58658 - time: 0:00:00.653305
# Patient AUC: 0.74543 - Slice AUC: 0.70613
#  Hold out:
# Val loss: 0.94859 - time: 0:00:00.794642
# Patient AUC: 0.40727 - Slice AUC: 0.46692
# Val AUC improved from 0.74202 to 0.74543
#
# Epoch 17/40:
# Train loss: 0.47112 - time: 0:00:02.051118
#  Validation:
# Val loss: 0.58762 - time: 0:00:00.643703
# Patient AUC: 0.75977 - Slice AUC: 0.71509
#  Hold out:
# Val loss: 0.95549 - time: 0:00:00.805748
# Patient AUC: 0.43091 - Slice AUC: 0.48106
# Val AUC improved from 0.74543 to 0.75977
#
# Epoch 18/40:
# Train loss: 0.45640 - time: 0:00:02.379841
#  Validation:
# Val loss: 0.59012 - time: 0:00:00.725106
# Patient AUC: 0.76445 - Slice AUC: 0.71062
#  Hold out:
# Val loss: 0.95784 - time: 0:00:00.786125
# Patient AUC: 0.43955 - Slice AUC: 0.49039
# Val AUC improved from 0.75977 to 0.76445
#
# Epoch 19/40:
# Train loss: 0.43966 - time: 0:00:02.057796
#  Validation:
# Val loss: 0.59931 - time: 0:00:00.636513
# Patient AUC: 0.76805 - Slice AUC: 0.71478
#  Hold out:
# Val loss: 1.05148 - time: 0:00:00.796775
# Patient AUC: 0.42045 - Slice AUC: 0.48344
# Val AUC improved from 0.76445 to 0.76805
#
# Epoch 20/40:
# Train loss: 0.42728 - time: 0:00:02.071018
#  Validation:
# Val loss: 0.62376 - time: 0:00:00.647874
# Patient AUC: 0.75004 - Slice AUC: 0.71624
#  Hold out:
# Val loss: 1.12671 - time: 0:00:00.782489
# Patient AUC: 0.44773 - Slice AUC: 0.49455
#
# Epoch 21/40:
# Train loss: 0.42032 - time: 0:00:01.999732
#  Validation:
# Val loss: 0.60912 - time: 0:00:00.636003
# Patient AUC: 0.78201 - Slice AUC: 0.71618
#  Hold out:
# Val loss: 1.11358 - time: 0:00:00.801270
# Patient AUC: 0.42318 - Slice AUC: 0.46891
# Val AUC improved from 0.76805 to 0.78201
#
# Epoch 22/40:
# Train loss: 0.41150 - time: 0:00:02.034395
#  Validation:
# Val loss: 0.63088 - time: 0:00:00.630797
# Patient AUC: 0.77414 - Slice AUC: 0.71865
#  Hold out:
# Val loss: 1.12773 - time: 0:00:00.793535
# Patient AUC: 0.43636 - Slice AUC: 0.49079
#
# Epoch 23/40:
# Train loss: 0.39576 - time: 0:00:02.008501
#  Validation:
# Val loss: 0.62305 - time: 0:00:00.629709
# Patient AUC: 0.76745 - Slice AUC: 0.72069
#  Hold out:
# Val loss: 1.22075 - time: 0:00:00.801241
# Patient AUC: 0.43273 - Slice AUC: 0.48770
#
# Epoch 24/40:
# Train loss: 0.38074 - time: 0:00:02.065154
#  Validation:
# Val loss: 0.64373 - time: 0:00:00.641001
# Patient AUC: 0.78606 - Slice AUC: 0.72030
#  Hold out:
# Val loss: 1.20251 - time: 0:00:00.769085
# Patient AUC: 0.43864 - Slice AUC: 0.48440
# Val AUC improved from 0.78201 to 0.78606
#
# Epoch 25/40:
# Train loss: 0.37106 - time: 0:00:02.065265
#  Validation:
# Val loss: 0.67462 - time: 0:00:00.659485
# Patient AUC: 0.76853 - Slice AUC: 0.71715
#  Hold out:
# Val loss: 1.35026 - time: 0:00:00.791682
# Patient AUC: 0.45864 - Slice AUC: 0.49728
#
# Epoch 26/40:
# Train loss: 0.36363 - time: 0:00:02.065559
#  Validation:
# Val loss: 0.65616 - time: 0:00:00.649420
# Patient AUC: 0.77473 - Slice AUC: 0.71649
#  Hold out:
# Val loss: 1.36342 - time: 0:00:00.785725
# Patient AUC: 0.45318 - Slice AUC: 0.48890
#
# Epoch 27/40:
# Train loss: 0.35411 - time: 0:00:02.034268
#  Validation:
# Val loss: 0.70933 - time: 0:00:00.634456
# Patient AUC: 0.77574 - Slice AUC: 0.71911
#  Hold out:
# Val loss: 1.48149 - time: 0:00:00.769109
# Patient AUC: 0.45545 - Slice AUC: 0.50178
#
# Epoch 28/40:
# Train loss: 0.35906 - time: 0:00:02.062861
#  Validation:
# Val loss: 0.69227 - time: 0:00:00.633367
# Patient AUC: 0.77986 - Slice AUC: 0.72668
#  Hold out:
# Val loss: 1.45231 - time: 0:00:00.800521
# Patient AUC: 0.42773 - Slice AUC: 0.48896
# Early stopping. Best model is epoch 24
# Val loss: 0.64373, Val auc: 0.78606
# Saving model...
# ### Train ['FLAIR'] on fold 1: ###
# 100%|██████████| 373/373 [00:01<00:00, 365.62it/s]
# Loading dataset: 100%|██████████| 6308/6308 [00:23<00:00, 266.29it/s]
# 100%|██████████| 373/373 [00:01<00:00, 357.77it/s]
# Loading dataset: 100%|██████████| 1578/1578 [00:06<00:00, 258.21it/s]
# 100%|██████████| 93/93 [00:00<00:00, 357.01it/s]
# Loading dataset: 100%|██████████| 2125/2125 [00:07<00:00, 266.32it/s]
# Epoch 1/40:
# Train loss: 0.67371 - time: 0:00:02.215062
#  Validation:
# Val loss: 0.67420 - time: 0:00:00.671680
# Patient AUC: 0.58556 - Slice AUC: 0.55465
#  Hold out:
# Val loss: 0.63517 - time: 0:00:00.773464
# Patient AUC: 0.66466 - Slice AUC: 0.63268
# Val AUC improved from -inf to 0.58556
#
# Epoch 2/40:
# Train loss: 0.66621 - time: 0:00:02.104331
#  Validation:
# Val loss: 0.67122 - time: 0:00:00.662026
# Patient AUC: 0.60601 - Slice AUC: 0.58577
#  Hold out:
# Val loss: 0.64180 - time: 0:00:00.788265
# Patient AUC: 0.67022 - Slice AUC: 0.63653
# Val AUC improved from 0.58556 to 0.60601
#
# Epoch 3/40:
# Train loss: 0.66014 - time: 0:00:02.085740
#  Validation:
# Val loss: 0.66591 - time: 0:00:00.665879
# Patient AUC: 0.60829 - Slice AUC: 0.57677
#  Hold out:
# Val loss: 0.62852 - time: 0:00:00.793537
# Patient AUC: 0.64425 - Slice AUC: 0.62523
# Val AUC improved from 0.60601 to 0.60829
#
# Epoch 4/40:
# Train loss: 0.65424 - time: 0:00:02.052915
#  Validation:
# Val loss: 0.66892 - time: 0:00:00.647539
# Patient AUC: 0.60192 - Slice AUC: 0.59358
#  Hold out:
# Val loss: 0.63656 - time: 0:00:00.789528
# Patient AUC: 0.68228 - Slice AUC: 0.64788
#
# Epoch 5/40:
# Train loss: 0.64958 - time: 0:00:02.108609
#  Validation:
# Val loss: 0.65411 - time: 0:00:00.658666
# Patient AUC: 0.62127 - Slice AUC: 0.61975
#  Hold out:
# Val loss: 0.63283 - time: 0:00:00.805406
# Patient AUC: 0.61920 - Slice AUC: 0.60356
# Val AUC improved from 0.60829 to 0.62127
#
# Epoch 6/40:
# Train loss: 0.64089 - time: 0:00:02.120596
#  Validation:
# Val loss: 0.66232 - time: 0:00:00.675958
# Patient AUC: 0.61508 - Slice AUC: 0.59327
#  Hold out:
# Val loss: 0.60542 - time: 0:00:00.828181
# Patient AUC: 0.65492 - Slice AUC: 0.63897
#
# Epoch 7/40:
# Train loss: 0.63259 - time: 0:00:02.079201
#  Validation:
# Val loss: 0.65320 - time: 0:00:00.645409
# Patient AUC: 0.62322 - Slice AUC: 0.61012
#  Hold out:
# Val loss: 0.59978 - time: 0:00:00.784813
# Patient AUC: 0.67440 - Slice AUC: 0.63826
# Val AUC improved from 0.62127 to 0.62322
#
# Epoch 8/40:
# Train loss: 0.62313 - time: 0:00:02.122375
#  Validation:
# Val loss: 0.64398 - time: 0:00:00.665140
# Patient AUC: 0.64139 - Slice AUC: 0.63280
#  Hold out:
# Val loss: 0.63152 - time: 0:00:00.793734
# Patient AUC: 0.64239 - Slice AUC: 0.61857
# Val AUC improved from 0.62322 to 0.64139
#
# Epoch 9/40:
# Train loss: 0.61279 - time: 0:00:02.054493
#  Validation:
# Val loss: 0.62999 - time: 0:00:00.660806
# Patient AUC: 0.67496 - Slice AUC: 0.65522
#  Hold out:
# Val loss: 0.63677 - time: 0:00:00.793851
# Patient AUC: 0.59972 - Slice AUC: 0.59075
# Val AUC improved from 0.64139 to 0.67496
#
# Epoch 10/40:
# Train loss: 0.60006 - time: 0:00:02.101249
#  Validation:
# Val loss: 0.63035 - time: 0:00:00.656571
# Patient AUC: 0.66881 - Slice AUC: 0.64407
#  Hold out:
# Val loss: 0.67336 - time: 0:00:01.000795
# Patient AUC: 0.56401 - Slice AUC: 0.55526
#
# Epoch 11/40:
# Train loss: 0.58701 - time: 0:00:02.124378
#  Validation:
# Val loss: 0.63581 - time: 0:00:00.696567
# Patient AUC: 0.66440 - Slice AUC: 0.66493
#  Hold out:
# Val loss: 0.68101 - time: 0:00:00.807343
# Patient AUC: 0.59369 - Slice AUC: 0.58657
#
# Epoch 12/40:
# Train loss: 0.57300 - time: 0:00:02.061881
#  Validation:
# Val loss: 0.63631 - time: 0:00:00.690353
# Patient AUC: 0.66586 - Slice AUC: 0.65081
#  Hold out:
# Val loss: 0.67272 - time: 0:00:00.812828
# Patient AUC: 0.51438 - Slice AUC: 0.54310
#
# Epoch 13/40:
# Train loss: 0.55858 - time: 0:00:02.077919
#  Validation:
# Val loss: 0.62621 - time: 0:00:00.673230
# Patient AUC: 0.68983 - Slice AUC: 0.65933
#  Hold out:
# Val loss: 0.68002 - time: 0:00:00.819455
# Patient AUC: 0.60065 - Slice AUC: 0.54962
# Val AUC improved from 0.67496 to 0.68983
#
# Epoch 14/40:
# Train loss: 0.54639 - time: 0:00:02.111946
#  Validation:
# Val loss: 0.65849 - time: 0:00:00.669491
# Patient AUC: 0.68062 - Slice AUC: 0.66460
#  Hold out:
# Val loss: 0.75317 - time: 0:00:00.790342
# Patient AUC: 0.63312 - Slice AUC: 0.59348
#
# Epoch 15/40:
# Train loss: 0.53466 - time: 0:00:02.190668
#  Validation:
# Val loss: 0.62946 - time: 0:00:00.678155
# Patient AUC: 0.70661 - Slice AUC: 0.67453
#  Hold out:
# Val loss: 0.72266 - time: 0:00:00.812023
# Patient AUC: 0.52505 - Slice AUC: 0.54339
# Val AUC improved from 0.68983 to 0.70661
#
# Epoch 16/40:
# Train loss: 0.51995 - time: 0:00:02.116131
#  Validation:
# Val loss: 0.62519 - time: 0:00:00.665720
# Patient AUC: 0.72102 - Slice AUC: 0.68544
#  Hold out:
# Val loss: 0.75067 - time: 0:00:00.807074
# Patient AUC: 0.60714 - Slice AUC: 0.54971
# Val AUC improved from 0.70661 to 0.72102
#
# Epoch 17/40:
# Train loss: 0.50822 - time: 0:00:02.132766
#  Validation:
# Val loss: 0.61484 - time: 0:00:00.752253
# Patient AUC: 0.71846 - Slice AUC: 0.68898
#  Hold out:
# Val loss: 0.74350 - time: 0:00:00.932865
# Patient AUC: 0.57746 - Slice AUC: 0.54830
#
# Epoch 18/40:
# Train loss: 0.49411 - time: 0:00:02.341778
#  Validation:
# Val loss: 0.62654 - time: 0:00:00.677091
# Patient AUC: 0.71433 - Slice AUC: 0.68730
#  Hold out:
# Val loss: 0.78683 - time: 0:00:00.816790
# Patient AUC: 0.58673 - Slice AUC: 0.55106
#
# Epoch 19/40:
# Train loss: 0.48444 - time: 0:00:02.145460
#  Validation:
# Val loss: 0.63812 - time: 0:00:00.684429
# Patient AUC: 0.71931 - Slice AUC: 0.68028
#  Hold out:
# Val loss: 0.81111 - time: 0:00:00.821347
# Patient AUC: 0.55659 - Slice AUC: 0.53286
#
# Epoch 20/40:
# Train loss: 0.47420 - time: 0:00:02.144956
#  Validation:
# Val loss: 0.62009 - time: 0:00:00.683220
# Patient AUC: 0.73997 - Slice AUC: 0.70189
#  Hold out:
# Val loss: 0.82530 - time: 0:00:00.803780
# Patient AUC: 0.59508 - Slice AUC: 0.56123
# Val AUC improved from 0.72102 to 0.73997
#
# Epoch 21/40:
# Train loss: 0.46271 - time: 0:00:02.117132
#  Validation:
# Val loss: 0.63270 - time: 0:00:00.679330
# Patient AUC: 0.72777 - Slice AUC: 0.70232
#  Hold out:
# Val loss: 0.82744 - time: 0:00:00.798350
# Patient AUC: 0.59740 - Slice AUC: 0.55257
#
# Epoch 22/40:
# Train loss: 0.45422 - time: 0:00:02.120566
#  Validation:
# Val loss: 0.66098 - time: 0:00:00.684978
# Patient AUC: 0.72027 - Slice AUC: 0.70021
#  Hold out:
# Val loss: 0.89525 - time: 0:00:00.818336
# Patient AUC: 0.59091 - Slice AUC: 0.56671
#
# Epoch 23/40:
# Train loss: 0.44372 - time: 0:00:02.154845
#  Validation:
# Val loss: 0.65844 - time: 0:00:00.677905
# Patient AUC: 0.72123 - Slice AUC: 0.69402
#  Hold out:
# Val loss: 0.88616 - time: 0:00:00.809248
# Patient AUC: 0.55473 - Slice AUC: 0.53391
#
# Epoch 24/40:
# Train loss: 0.43276 - time: 0:00:02.078968
#  Validation:
# Val loss: 0.65412 - time: 0:00:00.677185
# Patient AUC: 0.70562 - Slice AUC: 0.69477
#  Hold out:
# Val loss: 0.87975 - time: 0:00:00.797877
# Patient AUC: 0.48469 - Slice AUC: 0.53228
# Early stopping. Best model is epoch 20
# Val loss: 0.62009, Val auc: 0.73997
# Saving model...
# ### Train ['FLAIR'] on fold 2: ###
# 100%|██████████| 373/373 [00:01<00:00, 371.44it/s]
# Loading dataset: 100%|██████████| 6232/6232 [00:22<00:00, 277.83it/s]
# 100%|██████████| 373/373 [00:00<00:00, 377.13it/s]
# Loading dataset: 100%|██████████| 1558/1558 [00:05<00:00, 278.99it/s]
# 100%|██████████| 93/93 [00:00<00:00, 358.60it/s]
# Loading dataset: 100%|██████████| 2221/2221 [00:08<00:00, 251.04it/s]
# Epoch 1/40:
# Train loss: 0.67266 - time: 0:00:02.236673
#  Validation:
# Val loss: 0.65683 - time: 0:00:00.678651
# Patient AUC: 0.59066 - Slice AUC: 0.58152
#  Hold out:
# Val loss: 0.64267 - time: 0:00:00.820855
# Patient AUC: 0.64564 - Slice AUC: 0.55686
# Val AUC improved from -inf to 0.59066
#
# Epoch 2/40:
# Train loss: 0.66448 - time: 0:00:02.123719
#  Validation:
# Val loss: 0.64984 - time: 0:00:00.665084
# Patient AUC: 0.60455 - Slice AUC: 0.59419
#  Hold out:
# Val loss: 0.63748 - time: 0:00:00.820565
# Patient AUC: 0.68924 - Slice AUC: 0.59360
# Val AUC improved from 0.59066 to 0.60455
#
# Epoch 3/40:
# Train loss: 0.65914 - time: 0:00:02.047226
#  Validation:
# Val loss: 0.64099 - time: 0:00:00.689261
# Patient AUC: 0.61732 - Slice AUC: 0.61339
#  Hold out:
# Val loss: 0.65544 - time: 0:00:00.832367
# Patient AUC: 0.67393 - Slice AUC: 0.60042
# Val AUC improved from 0.60455 to 0.61732
#
# Epoch 4/40:
# Train loss: 0.65454 - time: 0:00:02.116159
#  Validation:
# Val loss: 0.63998 - time: 0:00:00.680039
# Patient AUC: 0.63018 - Slice AUC: 0.61676
#  Hold out:
# Val loss: 0.65300 - time: 0:00:00.828880
# Patient AUC: 0.69712 - Slice AUC: 0.59752
# Val AUC improved from 0.61732 to 0.63018
#
# Epoch 5/40:
# Train loss: 0.64644 - time: 0:00:02.114699
#  Validation:
# Val loss: 0.62963 - time: 0:00:00.655657
# Patient AUC: 0.64688 - Slice AUC: 0.63918
#  Hold out:
# Val loss: 0.66426 - time: 0:00:00.831090
# Patient AUC: 0.60575 - Slice AUC: 0.57121
# Val AUC improved from 0.63018 to 0.64688
#
# Epoch 6/40:
# Train loss: 0.63963 - time: 0:00:02.076128
#  Validation:
# Val loss: 0.62464 - time: 0:00:00.659666
# Patient AUC: 0.66889 - Slice AUC: 0.65279
#  Hold out:
# Val loss: 0.69476 - time: 0:00:00.799140
# Patient AUC: 0.66837 - Slice AUC: 0.57931
# Val AUC improved from 0.64688 to 0.66889
#
# Epoch 7/40:
# Train loss: 0.63020 - time: 0:00:02.056949
#  Validation:
# Val loss: 0.61857 - time: 0:00:00.659088
# Patient AUC: 0.66923 - Slice AUC: 0.65197
#  Hold out:
# Val loss: 0.70988 - time: 0:00:00.831834
# Patient AUC: 0.61920 - Slice AUC: 0.56562
# Val AUC improved from 0.66889 to 0.66923
#
# Epoch 8/40:
# Train loss: 0.62322 - time: 0:00:02.081904
#  Validation:
# Val loss: 0.62651 - time: 0:00:00.678962
# Patient AUC: 0.68843 - Slice AUC: 0.66152
#  Hold out:
# Val loss: 0.75729 - time: 0:00:00.815330
# Patient AUC: 0.61735 - Slice AUC: 0.54839
# Val AUC improved from 0.66923 to 0.68843
#
# Epoch 9/40:
# Train loss: 0.61636 - time: 0:00:02.075488
#  Validation:
# Val loss: 0.60989 - time: 0:00:00.659280
# Patient AUC: 0.69309 - Slice AUC: 0.66086
#  Hold out:
# Val loss: 0.74571 - time: 0:00:00.805603
# Patient AUC: 0.63822 - Slice AUC: 0.56572
# Val AUC improved from 0.68843 to 0.69309
#
# Epoch 10/40:
# Train loss: 0.60679 - time: 0:00:02.094032
#  Validation:
# Val loss: 0.60365 - time: 0:00:00.665360
# Patient AUC: 0.70452 - Slice AUC: 0.66596
#  Hold out:
# Val loss: 0.71154 - time: 0:00:00.803770
# Patient AUC: 0.64193 - Slice AUC: 0.56630
# Val AUC improved from 0.69309 to 0.70452
#
# Epoch 11/40:
# Train loss: 0.59182 - time: 0:00:02.062843
#  Validation:
# Val loss: 0.60304 - time: 0:00:00.671205
# Patient AUC: 0.70917 - Slice AUC: 0.67335
#  Hold out:
# Val loss: 0.78684 - time: 0:00:00.816633
# Patient AUC: 0.58349 - Slice AUC: 0.53544
# Val AUC improved from 0.70452 to 0.70917
#
# Epoch 12/40:
# Train loss: 0.58200 - time: 0:00:02.101418
#  Validation:
# Val loss: 0.59409 - time: 0:00:00.662339
# Patient AUC: 0.72018 - Slice AUC: 0.69107
#  Hold out:
# Val loss: 0.80519 - time: 0:00:00.824065
# Patient AUC: 0.61920 - Slice AUC: 0.54034
# Val AUC improved from 0.70917 to 0.72018
#
# Epoch 13/40:
# Train loss: 0.56738 - time: 0:00:02.071131
#  Validation:
# Val loss: 0.58809 - time: 0:00:00.683306
# Patient AUC: 0.72595 - Slice AUC: 0.69275
#  Hold out:
# Val loss: 0.81152 - time: 0:00:00.833957
# Patient AUC: 0.60946 - Slice AUC: 0.54126
# Val AUC improved from 0.72018 to 0.72595
#
# Epoch 14/40:
# Train loss: 0.55659 - time: 0:00:02.112487
#  Validation:
# Val loss: 0.58941 - time: 0:00:00.651689
# Patient AUC: 0.72880 - Slice AUC: 0.69952
#  Hold out:
# Val loss: 0.89211 - time: 0:00:00.817562
# Patient AUC: 0.62477 - Slice AUC: 0.54217
# Val AUC improved from 0.72595 to 0.72880
#
# Epoch 15/40:
# Train loss: 0.54708 - time: 0:00:02.070819
#  Validation:
# Val loss: 0.59260 - time: 0:00:00.661418
# Patient AUC: 0.72191 - Slice AUC: 0.69571
#  Hold out:
# Val loss: 0.89949 - time: 0:00:00.817584
# Patient AUC: 0.64610 - Slice AUC: 0.54658
#
# Epoch 16/40:
# Train loss: 0.53412 - time: 0:00:02.092755
#  Validation:
# Val loss: 0.59151 - time: 0:00:00.660684
# Patient AUC: 0.73199 - Slice AUC: 0.68817
#  Hold out:
# Val loss: 0.88864 - time: 0:00:00.820517
# Patient AUC: 0.53664 - Slice AUC: 0.50823
# Val AUC improved from 0.72880 to 0.73199
#
# Epoch 17/40:
# Train loss: 0.51646 - time: 0:00:02.060801
#  Validation:
# Val loss: 0.60285 - time: 0:00:00.676283
# Patient AUC: 0.72387 - Slice AUC: 0.69311
#  Hold out:
# Val loss: 0.98145 - time: 0:00:00.819890
# Patient AUC: 0.59601 - Slice AUC: 0.52378
#
# Epoch 18/40:
# Train loss: 0.50594 - time: 0:00:02.120132
#  Validation:
# Val loss: 0.60431 - time: 0:00:00.682280
# Patient AUC: 0.73761 - Slice AUC: 0.69344
#  Hold out:
# Val loss: 1.02359 - time: 0:00:00.824881
# Patient AUC: 0.56262 - Slice AUC: 0.51439
# Val AUC improved from 0.73199 to 0.73761
#
# Epoch 19/40:
# Train loss: 0.49379 - time: 0:00:02.127934
#  Validation:
# Val loss: 0.59736 - time: 0:00:00.672695
# Patient AUC: 0.72710 - Slice AUC: 0.69214
#  Hold out:
# Val loss: 0.99072 - time: 0:00:00.818258
# Patient AUC: 0.54963 - Slice AUC: 0.50027
#
# Epoch 20/40:
# Train loss: 0.48070 - time: 0:00:02.044423
#  Validation:
# Val loss: 0.61558 - time: 0:00:00.671871
# Patient AUC: 0.74061 - Slice AUC: 0.70253
#  Hold out:
# Val loss: 1.15557 - time: 0:00:00.837649
# Patient AUC: 0.58071 - Slice AUC: 0.52609
# Val AUC improved from 0.73761 to 0.74061
#
# Epoch 21/40:
# Train loss: 0.46553 - time: 0:00:02.412364
#  Validation:
# Val loss: 0.62277 - time: 0:00:00.755463
# Patient AUC: 0.72476 - Slice AUC: 0.70409
#  Hold out:
# Val loss: 1.06484 - time: 0:00:00.842304
# Patient AUC: 0.60390 - Slice AUC: 0.53159
#
# Epoch 22/40:
# Train loss: 0.46004 - time: 0:00:02.138346
#  Validation:
# Val loss: 0.61564 - time: 0:00:00.680891
# Patient AUC: 0.73703 - Slice AUC: 0.69209
#  Hold out:
# Val loss: 1.08754 - time: 0:00:00.825976
# Patient AUC: 0.52968 - Slice AUC: 0.49306
#
# Epoch 23/40:
# Train loss: 0.44676 - time: 0:00:02.117191
#  Validation:
# Val loss: 0.62509 - time: 0:00:00.661295
# Patient AUC: 0.74307 - Slice AUC: 0.70065
#  Hold out:
# Val loss: 1.09789 - time: 0:00:00.803373
# Patient AUC: 0.56911 - Slice AUC: 0.51527
# Val AUC improved from 0.74061 to 0.74307
#
# Epoch 24/40:
# Train loss: 0.43665 - time: 0:00:02.062446
#  Validation:
# Val loss: 0.62777 - time: 0:00:00.669253
# Patient AUC: 0.75085 - Slice AUC: 0.71325
#  Hold out:
# Val loss: 1.17777 - time: 0:00:00.827495
# Patient AUC: 0.57375 - Slice AUC: 0.52369
# Val AUC improved from 0.74307 to 0.75085
#
# Epoch 25/40:
# Train loss: 0.42404 - time: 0:00:02.075175
#  Validation:
# Val loss: 0.63791 - time: 0:00:00.673599
# Patient AUC: 0.74646 - Slice AUC: 0.70480
#  Hold out:
# Val loss: 1.24478 - time: 0:00:00.810427
# Patient AUC: 0.53942 - Slice AUC: 0.49683
#
# Epoch 26/40:
# Train loss: 0.41502 - time: 0:00:02.051060
#  Validation:
# Val loss: 0.65269 - time: 0:00:00.680573
# Patient AUC: 0.74769 - Slice AUC: 0.70557
#  Hold out:
# Val loss: 1.31390 - time: 0:00:00.844597
# Patient AUC: 0.57096 - Slice AUC: 0.52088
#
# Epoch 27/40:
# Train loss: 0.40715 - time: 0:00:02.081464
#  Validation:
# Val loss: 0.65731 - time: 0:00:00.662045
# Patient AUC: 0.74227 - Slice AUC: 0.70592
#  Hold out:
# Val loss: 1.30479 - time: 0:00:00.839304
# Patient AUC: 0.55288 - Slice AUC: 0.50379
#
# Epoch 28/40:
# Train loss: 0.39272 - time: 0:00:02.055115
#  Validation:
# Val loss: 0.68888 - time: 0:00:00.682121
# Patient AUC: 0.74280 - Slice AUC: 0.71029
#  Hold out:
# Val loss: 1.43524 - time: 0:00:00.833989
# Patient AUC: 0.55612 - Slice AUC: 0.50652
# Early stopping. Best model is epoch 24
# Val loss: 0.62777, Val auc: 0.75085
# Saving model...
# ### Train ['FLAIR'] on fold 3: ###
# 100%|██████████| 373/373 [00:01<00:00, 367.05it/s]
# Loading dataset: 100%|██████████| 6544/6544 [00:23<00:00, 276.57it/s]
# 100%|██████████| 373/373 [00:01<00:00, 368.85it/s]
# Loading dataset: 100%|██████████| 1637/1637 [00:06<00:00, 260.10it/s]
# 100%|██████████| 93/93 [00:00<00:00, 398.97it/s]
# Loading dataset: 100%|██████████| 1830/1830 [00:07<00:00, 230.50it/s]
# Epoch 1/40:
# Train loss: 0.65752 - time: 0:00:02.255945
#  Validation:
# Val loss: 0.65736 - time: 0:00:00.689197
# Patient AUC: 0.60205 - Slice AUC: 0.60733
#  Hold out:
# Val loss: 0.67657 - time: 0:00:00.743701
# Patient AUC: 0.58071 - Slice AUC: 0.55032
# Val AUC improved from -inf to 0.60205
#
# Epoch 2/40:
# Train loss: 0.64728 - time: 0:00:02.172149
#  Validation:
# Val loss: 0.65222 - time: 0:00:00.682086
# Patient AUC: 0.61385 - Slice AUC: 0.60542
#  Hold out:
# Val loss: 0.68619 - time: 0:00:00.741524
# Patient AUC: 0.56354 - Slice AUC: 0.51955
# Val AUC improved from 0.60205 to 0.61385
#
# Epoch 3/40:
# Train loss: 0.64305 - time: 0:00:02.175517
#  Validation:
# Val loss: 0.64601 - time: 0:00:00.688644
# Patient AUC: 0.62855 - Slice AUC: 0.62177
#  Hold out:
# Val loss: 0.69347 - time: 0:00:00.734568
# Patient AUC: 0.55612 - Slice AUC: 0.53554
# Val AUC improved from 0.61385 to 0.62855
#
# Epoch 4/40:
# Train loss: 0.63735 - time: 0:00:02.146590
#  Validation:
# Val loss: 0.64203 - time: 0:00:00.690016
# Patient AUC: 0.63637 - Slice AUC: 0.63100
#  Hold out:
# Val loss: 0.69921 - time: 0:00:00.730338
# Patient AUC: 0.57514 - Slice AUC: 0.53591
# Val AUC improved from 0.62855 to 0.63637
#
# Epoch 5/40:
# Train loss: 0.63154 - time: 0:00:02.141371
#  Validation:
# Val loss: 0.64423 - time: 0:00:00.675481
# Patient AUC: 0.64748 - Slice AUC: 0.63746
#  Hold out:
# Val loss: 0.71780 - time: 0:00:00.750672
# Patient AUC: 0.57328 - Slice AUC: 0.53409
# Val AUC improved from 0.63637 to 0.64748
#
# Epoch 6/40:
# Train loss: 0.62591 - time: 0:00:02.221934
#  Validation:
# Val loss: 0.63282 - time: 0:00:00.700474
# Patient AUC: 0.65135 - Slice AUC: 0.63963
#  Hold out:
# Val loss: 0.72663 - time: 0:00:00.750566
# Patient AUC: 0.57328 - Slice AUC: 0.52246
# Val AUC improved from 0.64748 to 0.65135
#
# Epoch 7/40:
# Train loss: 0.61779 - time: 0:00:02.211398
#  Validation:
# Val loss: 0.62804 - time: 0:00:00.688893
# Patient AUC: 0.65592 - Slice AUC: 0.64185
#  Hold out:
# Val loss: 0.71174 - time: 0:00:00.727683
# Patient AUC: 0.56865 - Slice AUC: 0.52964
# Val AUC improved from 0.65135 to 0.65592
#
# Epoch 8/40:
# Train loss: 0.61034 - time: 0:00:02.296080
#  Validation:
# Val loss: 0.62129 - time: 0:00:00.687312
# Patient AUC: 0.66510 - Slice AUC: 0.65137
#  Hold out:
# Val loss: 0.72030 - time: 0:00:00.733022
# Patient AUC: 0.59091 - Slice AUC: 0.51932
# Val AUC improved from 0.65592 to 0.66510
#
# Epoch 9/40:
# Train loss: 0.60393 - time: 0:00:02.238820
#  Validation:
# Val loss: 0.62102 - time: 0:00:00.703970
# Patient AUC: 0.67467 - Slice AUC: 0.65803
#  Hold out:
# Val loss: 0.70043 - time: 0:00:00.754653
# Patient AUC: 0.60761 - Slice AUC: 0.52773
# Val AUC improved from 0.66510 to 0.67467
#
# Epoch 10/40:
# Train loss: 0.59656 - time: 0:00:02.193329
#  Validation:
# Val loss: 0.61635 - time: 0:00:00.683574
# Patient AUC: 0.67880 - Slice AUC: 0.66609
#  Hold out:
# Val loss: 0.74031 - time: 0:00:00.717113
# Patient AUC: 0.60714 - Slice AUC: 0.52311
# Val AUC improved from 0.67467 to 0.67880
#
# Epoch 11/40:
# Train loss: 0.58418 - time: 0:00:02.136351
#  Validation:
# Val loss: 0.60992 - time: 0:00:00.714884
# Patient AUC: 0.67668 - Slice AUC: 0.68226
#  Hold out:
# Val loss: 0.73928 - time: 0:00:00.739007
# Patient AUC: 0.61039 - Slice AUC: 0.53514
#
# Epoch 12/40:
# Train loss: 0.57551 - time: 0:00:02.159501
#  Validation:
# Val loss: 0.60770 - time: 0:00:00.681917
# Patient AUC: 0.68538 - Slice AUC: 0.67750
#  Hold out:
# Val loss: 0.75335 - time: 0:00:00.752506
# Patient AUC: 0.59508 - Slice AUC: 0.53021
# Val AUC improved from 0.67880 to 0.68538
#
# Epoch 13/40:
# Train loss: 0.57000 - time: 0:00:02.146512
#  Validation:
# Val loss: 0.60778 - time: 0:00:00.678270
# Patient AUC: 0.68213 - Slice AUC: 0.67675
#  Hold out:
# Val loss: 0.76353 - time: 0:00:00.757495
# Patient AUC: 0.56911 - Slice AUC: 0.52778
#
# Epoch 14/40:
# Train loss: 0.55845 - time: 0:00:02.181279
#  Validation:
# Val loss: 0.60880 - time: 0:00:00.689861
# Patient AUC: 0.68348 - Slice AUC: 0.67568
#  Hold out:
# Val loss: 0.76975 - time: 0:00:00.763958
# Patient AUC: 0.56633 - Slice AUC: 0.52613
#
# Epoch 15/40:
# Train loss: 0.55000 - time: 0:00:02.142687
#  Validation:
# Val loss: 0.59258 - time: 0:00:00.686243
# Patient AUC: 0.71517 - Slice AUC: 0.69890
#  Hold out:
# Val loss: 0.75383 - time: 0:00:00.725018
# Patient AUC: 0.61039 - Slice AUC: 0.52459
# Val AUC improved from 0.68538 to 0.71517
#
# Epoch 16/40:
# Train loss: 0.54145 - time: 0:00:02.153936
#  Validation:
# Val loss: 0.61629 - time: 0:00:00.710968
# Patient AUC: 0.68399 - Slice AUC: 0.68166
#  Hold out:
# Val loss: 0.81798 - time: 0:00:00.733668
# Patient AUC: 0.57885 - Slice AUC: 0.49771
#
# Epoch 17/40:
# Train loss: 0.53176 - time: 0:00:02.218214
#  Validation:
# Val loss: 0.59969 - time: 0:00:00.681029
# Patient AUC: 0.70797 - Slice AUC: 0.69794
#  Hold out:
# Val loss: 0.81716 - time: 0:00:00.737454
# Patient AUC: 0.57560 - Slice AUC: 0.51807
#
# Epoch 18/40:
# Train loss: 0.52231 - time: 0:00:02.158988
#  Validation:
# Val loss: 0.58799 - time: 0:00:00.692332
# Patient AUC: 0.71846 - Slice AUC: 0.70498
#  Hold out:
# Val loss: 0.79121 - time: 0:00:00.732303
# Patient AUC: 0.57792 - Slice AUC: 0.52089
# Val AUC improved from 0.71517 to 0.71846
#
# Epoch 19/40:
# Train loss: 0.51307 - time: 0:00:02.228568
#  Validation:
# Val loss: 0.61097 - time: 0:00:00.711752
# Patient AUC: 0.70691 - Slice AUC: 0.69947
#  Hold out:
# Val loss: 0.83161 - time: 0:00:00.746588
# Patient AUC: 0.60065 - Slice AUC: 0.54198
#
# Epoch 20/40:
# Train loss: 0.50294 - time: 0:00:02.400354
#  Validation:
# Val loss: 0.59293 - time: 0:00:00.788493
# Patient AUC: 0.72376 - Slice AUC: 0.70943
#  Hold out:
# Val loss: 0.86516 - time: 0:00:00.814179
# Patient AUC: 0.56772 - Slice AUC: 0.51664
# Val AUC improved from 0.71846 to 0.72376
#
# Epoch 21/40:
# Train loss: 0.49322 - time: 0:00:02.131777
#  Validation:
# Val loss: 0.62083 - time: 0:00:00.710094
# Patient AUC: 0.70175 - Slice AUC: 0.70062
#  Hold out:
# Val loss: 0.87186 - time: 0:00:00.724157
# Patient AUC: 0.59137 - Slice AUC: 0.53538
#
# Epoch 22/40:
# Train loss: 0.48166 - time: 0:00:02.147344
#  Validation:
# Val loss: 0.61159 - time: 0:00:00.683146
# Patient AUC: 0.73015 - Slice AUC: 0.72168
#  Hold out:
# Val loss: 0.93993 - time: 0:00:00.741713
# Patient AUC: 0.55009 - Slice AUC: 0.52584
# Val AUC improved from 0.72376 to 0.73015
#
# Epoch 23/40:
# Train loss: 0.48111 - time: 0:00:02.168782
#  Validation:
# Val loss: 0.59949 - time: 0:00:00.698893
# Patient AUC: 0.73779 - Slice AUC: 0.71813
#  Hold out:
# Val loss: 0.89992 - time: 0:00:00.723006
# Patient AUC: 0.58952 - Slice AUC: 0.54140
# Val AUC improved from 0.73015 to 0.73779
#
# Epoch 24/40:
# Train loss: 0.46953 - time: 0:00:02.185699
#  Validation:
# Val loss: 0.60810 - time: 0:00:00.678188
# Patient AUC: 0.72657 - Slice AUC: 0.71860
#  Hold out:
# Val loss: 0.92776 - time: 0:00:00.725889
# Patient AUC: 0.55427 - Slice AUC: 0.52602
#
# Epoch 25/40:
# Train loss: 0.46017 - time: 0:00:02.117325
#  Validation:
# Val loss: 0.65155 - time: 0:00:00.668175
# Patient AUC: 0.71385 - Slice AUC: 0.70279
#  Hold out:
# Val loss: 1.04597 - time: 0:00:00.746750
# Patient AUC: 0.50046 - Slice AUC: 0.51157
#
# Epoch 26/40:
# Train loss: 0.45245 - time: 0:00:02.158581
#  Validation:
# Val loss: 0.62398 - time: 0:00:00.690116
# Patient AUC: 0.73333 - Slice AUC: 0.71437
#  Hold out:
# Val loss: 0.99827 - time: 0:00:00.731265
# Patient AUC: 0.51113 - Slice AUC: 0.52451
#
# Epoch 27/40:
# Train loss: 0.43504 - time: 0:00:02.184080
#  Validation:
# Val loss: 0.62963 - time: 0:00:00.696098
# Patient AUC: 0.73885 - Slice AUC: 0.72268
#  Hold out:
# Val loss: 1.08693 - time: 0:00:00.752383
# Patient AUC: 0.54453 - Slice AUC: 0.51597
# Val AUC improved from 0.73779 to 0.73885
#
# Epoch 28/40:
# Train loss: 0.43264 - time: 0:00:02.118414
#  Validation:
# Val loss: 0.62882 - time: 0:00:00.696093
# Patient AUC: 0.74518 - Slice AUC: 0.71394
#  Hold out:
# Val loss: 1.02693 - time: 0:00:00.742118
# Patient AUC: 0.51994 - Slice AUC: 0.51313
# Val AUC improved from 0.73885 to 0.74518
#
# Epoch 29/40:
# Train loss: 0.42649 - time: 0:00:02.178365
#  Validation:
# Val loss: 0.62843 - time: 0:00:00.704283
# Patient AUC: 0.74152 - Slice AUC: 0.71526
#  Hold out:
# Val loss: 1.00439 - time: 0:00:00.742420
# Patient AUC: 0.55195 - Slice AUC: 0.53080
#
# Epoch 30/40:
# Train loss: 0.41671 - time: 0:00:02.158360
#  Validation:
# Val loss: 0.65996 - time: 0:00:00.679850
# Patient AUC: 0.73183 - Slice AUC: 0.72343
#  Hold out:
# Val loss: 1.14098 - time: 0:00:00.756016
# Patient AUC: 0.54035 - Slice AUC: 0.52312
#
# Epoch 31/40:
# Train loss: 0.41026 - time: 0:00:02.183663
#  Validation:
# Val loss: 0.66296 - time: 0:00:00.704671
# Patient AUC: 0.73023 - Slice AUC: 0.71420
#  Hold out:
# Val loss: 1.11476 - time: 0:00:00.746153
# Patient AUC: 0.53664 - Slice AUC: 0.51488
#
# Epoch 32/40:
# Train loss: 0.40850 - time: 0:00:02.145065
#  Validation:
# Val loss: 0.68178 - time: 0:00:00.699994
# Patient AUC: 0.74309 - Slice AUC: 0.70714
#  Hold out:
# Val loss: 1.13817 - time: 0:00:00.710201
# Patient AUC: 0.54360 - Slice AUC: 0.51732
# Early stopping. Best model is epoch 28
# Val loss: 0.62882, Val auc: 0.74518
# Saving model...
# ### Train ['FLAIR'] on fold 4: ###
# 100%|██████████| 373/373 [00:01<00:00, 368.55it/s]
# Loading dataset: 100%|██████████| 6710/6710 [00:24<00:00, 278.80it/s]
# 100%|██████████| 373/373 [00:01<00:00, 353.83it/s]
# Loading dataset: 100%|██████████| 1678/1678 [00:06<00:00, 273.42it/s]
# 100%|██████████| 93/93 [00:00<00:00, 420.72it/s]
# Loading dataset: 100%|██████████| 1623/1623 [00:06<00:00, 253.25it/s]
# Epoch 1/40:
# Train loss: 0.65554 - time: 0:00:02.347694
#  Validation:
# Val loss: 0.65922 - time: 0:00:00.696772
# Patient AUC: 0.61588 - Slice AUC: 0.60258
#  Hold out:
# Val loss: 0.68093 - time: 0:00:00.674670
# Patient AUC: 0.58673 - Slice AUC: 0.55773
# Val AUC improved from -inf to 0.61588
#
# Epoch 2/40:
# Train loss: 0.64959 - time: 0:00:02.221899
#  Validation:
# Val loss: 0.65326 - time: 0:00:00.675981
# Patient AUC: 0.61618 - Slice AUC: 0.60544
#  Hold out:
# Val loss: 0.67937 - time: 0:00:00.693027
# Patient AUC: 0.58024 - Slice AUC: 0.54807
# Val AUC improved from 0.61588 to 0.61618
#
# Epoch 3/40:
# Train loss: 0.64247 - time: 0:00:02.209633
#  Validation:
# Val loss: 0.66525 - time: 0:00:00.671889
# Patient AUC: 0.61843 - Slice AUC: 0.61305
#  Hold out:
# Val loss: 0.69800 - time: 0:00:00.677612
# Patient AUC: 0.60250 - Slice AUC: 0.54201
# Val AUC improved from 0.61618 to 0.61843
#
# Epoch 4/40:
# Train loss: 0.63762 - time: 0:00:02.186776
#  Validation:
# Val loss: 0.64438 - time: 0:00:00.692766
# Patient AUC: 0.63015 - Slice AUC: 0.62931
#  Hold out:
# Val loss: 0.67141 - time: 0:00:00.690041
# Patient AUC: 0.59879 - Slice AUC: 0.57039
# Val AUC improved from 0.61843 to 0.63015
#
# Epoch 5/40:
# Train loss: 0.63244 - time: 0:00:02.209915
#  Validation:
# Val loss: 0.63792 - time: 0:00:00.726880
# Patient AUC: 0.63858 - Slice AUC: 0.63762
#  Hold out:
# Val loss: 0.68022 - time: 0:00:00.686260
# Patient AUC: 0.60204 - Slice AUC: 0.56043
# Val AUC improved from 0.63015 to 0.63858
#
# Epoch 6/40:
# Train loss: 0.62200 - time: 0:00:02.239551
#  Validation:
# Val loss: 0.63624 - time: 0:00:00.714792
# Patient AUC: 0.63804 - Slice AUC: 0.63962
#  Hold out:
# Val loss: 0.68505 - time: 0:00:00.674123
# Patient AUC: 0.60390 - Slice AUC: 0.56024
#
# Epoch 7/40:
# Train loss: 0.61328 - time: 0:00:02.229559
#  Validation:
# Val loss: 0.63561 - time: 0:00:00.682992
# Patient AUC: 0.63787 - Slice AUC: 0.63449
#  Hold out:
# Val loss: 0.68619 - time: 0:00:00.686959
# Patient AUC: 0.59740 - Slice AUC: 0.55125
#
# Epoch 8/40:
# Train loss: 0.60258 - time: 0:00:02.204917
#  Validation:
# Val loss: 0.63906 - time: 0:00:00.699969
# Patient AUC: 0.65745 - Slice AUC: 0.64388
#  Hold out:
# Val loss: 0.70364 - time: 0:00:00.687478
# Patient AUC: 0.61271 - Slice AUC: 0.55412
# Val AUC improved from 0.63858 to 0.65745
#
# Epoch 9/40:
# Train loss: 0.59127 - time: 0:00:02.231982
#  Validation:
# Val loss: 0.63732 - time: 0:00:00.696030
# Patient AUC: 0.63727 - Slice AUC: 0.64703
#  Hold out:
# Val loss: 0.68259 - time: 0:00:00.694251
# Patient AUC: 0.63590 - Slice AUC: 0.54812
#
# Epoch 10/40:
# Train loss: 0.57808 - time: 0:00:02.202470
#  Validation:
# Val loss: 0.62755 - time: 0:00:00.702778
# Patient AUC: 0.68350 - Slice AUC: 0.66224
#  Hold out:
# Val loss: 0.72730 - time: 0:00:00.704750
# Patient AUC: 0.58627 - Slice AUC: 0.52844
# Val AUC improved from 0.65745 to 0.68350
#
# Epoch 11/40:
# Train loss: 0.56569 - time: 0:00:02.223204
#  Validation:
# Val loss: 0.61481 - time: 0:00:00.691210
# Patient AUC: 0.70542 - Slice AUC: 0.67828
#  Hold out:
# Val loss: 0.72273 - time: 0:00:00.678185
# Patient AUC: 0.57375 - Slice AUC: 0.52016
# Val AUC improved from 0.68350 to 0.70542
#
# Epoch 12/40:
# Train loss: 0.55533 - time: 0:00:02.211704
#  Validation:
# Val loss: 0.61061 - time: 0:00:00.701558
# Patient AUC: 0.70948 - Slice AUC: 0.67834
#  Hold out:
# Val loss: 0.71451 - time: 0:00:00.706090
# Patient AUC: 0.60529 - Slice AUC: 0.53283
# Val AUC improved from 0.70542 to 0.70948
#
# Epoch 13/40:
# Train loss: 0.54190 - time: 0:00:02.211358
#  Validation:
# Val loss: 0.62099 - time: 0:00:00.714494
# Patient AUC: 0.69448 - Slice AUC: 0.66373
#  Hold out:
# Val loss: 0.73079 - time: 0:00:00.681381
# Patient AUC: 0.57746 - Slice AUC: 0.51318
#
# Epoch 14/40:
# Train loss: 0.52913 - time: 0:00:02.211136
#  Validation:
# Val loss: 0.60453 - time: 0:00:00.679420
# Patient AUC: 0.72446 - Slice AUC: 0.68828
#  Hold out:
# Val loss: 0.75206 - time: 0:00:00.694411
# Patient AUC: 0.57514 - Slice AUC: 0.51492
# Val AUC improved from 0.70948 to 0.72446
#
# Epoch 15/40:
# Train loss: 0.51410 - time: 0:00:02.200354
#  Validation:
# Val loss: 0.63332 - time: 0:00:00.719190
# Patient AUC: 0.70915 - Slice AUC: 0.68306
#  Hold out:
# Val loss: 0.83356 - time: 0:00:00.710089
# Patient AUC: 0.61503 - Slice AUC: 0.54639
#
# Epoch 16/40:
# Train loss: 0.50507 - time: 0:00:02.509125
#  Validation:
# Val loss: 0.60335 - time: 0:00:00.781604
# Patient AUC: 0.73641 - Slice AUC: 0.70467
#  Hold out:
# Val loss: 0.84087 - time: 0:00:00.722503
# Patient AUC: 0.53942 - Slice AUC: 0.51479
# Val AUC improved from 0.72446 to 0.73641
#
# Epoch 17/40:
# Train loss: 0.49521 - time: 0:00:02.230268
#  Validation:
# Val loss: 0.61805 - time: 0:00:00.708825
# Patient AUC: 0.73181 - Slice AUC: 0.70322
#  Hold out:
# Val loss: 0.81108 - time: 0:00:00.685223
# Patient AUC: 0.58998 - Slice AUC: 0.52178
#
# Epoch 18/40:
# Train loss: 0.48229 - time: 0:00:02.224183
#  Validation:
# Val loss: 0.61261 - time: 0:00:00.714237
# Patient AUC: 0.72523 - Slice AUC: 0.70859
#  Hold out:
# Val loss: 0.83778 - time: 0:00:00.689451
# Patient AUC: 0.57792 - Slice AUC: 0.52738
#
# Epoch 19/40:
# Train loss: 0.47407 - time: 0:00:02.205091
#  Validation:
# Val loss: 0.61176 - time: 0:00:00.687910
# Patient AUC: 0.73020 - Slice AUC: 0.70919
#  Hold out:
# Val loss: 0.83642 - time: 0:00:00.702458
# Patient AUC: 0.56865 - Slice AUC: 0.51657
#
# Epoch 20/40:
# Train loss: 0.45639 - time: 0:00:02.245875
#  Validation:
# Val loss: 0.62018 - time: 0:00:00.690298
# Patient AUC: 0.73641 - Slice AUC: 0.70139
#  Hold out:
# Val loss: 0.87870 - time: 0:00:00.679723
# Patient AUC: 0.57143 - Slice AUC: 0.51493
# Early stopping. Best model is epoch 16
# Val loss: 0.60335, Val auc: 0.73641
# Saving model...

# %% [markdown]
# Evaluate

# %%
metrics = []
results = []
find_weight = lambda x: [w for w in os.listdir() if x in w][0]
weights_paths = [f'{"_".join(mri_types)}_fold{fold}' for fold in range(n_folds)]
weights_paths = [find_weight(x) for x in weights_paths]
for fold, weights_path in enumerate(weights_paths):
    print(f'### Evaluate {mri_types} on fold {fold}: ###')
    _, _, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                     fold=fold,
                                                     cache_rate=0.0)
    pipeline.load_model(weights_path)
    val_metric, val_result = pipeline.evaluate(val_holdout_ds, batch_size=batch_size, verbose=True)
    metrics.append(val_metric)
    results.append(val_result)
results = pd.concat(results, ignore_index=True)
mean_auc = np.mean(metrics)
oof_auc = roc_auc_score(results['label'], results['probability'])
print('---')
print(f'{mri_types} holdout result:')
print(' Mean AUC: {:.5f}'.format(mean_auc))
print(' Out-of-fold AUC: {:.5f}'.format(oof_auc))
print('---')
# Out:
# ### Evaluate ['FLAIR'] on fold 0: ###
# 100%|██████████| 372/372 [00:00<00:00, 381.52it/s]
# 100%|██████████| 372/372 [00:00<00:00, 390.53it/s]
# 100%|██████████| 94/94 [00:00<00:00, 346.92it/s]
#  Hold out:
# Val loss: 1.20251 - time: 0:00:05.529822
# Patient AUC: 0.43864 - Slice AUC: 0.48440
# ### Evaluate ['FLAIR'] on fold 1: ###
# 100%|██████████| 373/373 [00:00<00:00, 373.56it/s]
# 100%|██████████| 373/373 [00:00<00:00, 386.78it/s]
# 100%|██████████| 93/93 [00:00<00:00, 341.35it/s]
#  Hold out:
# Val loss: 0.82530 - time: 0:00:05.144009
# Patient AUC: 0.59508 - Slice AUC: 0.56123
# ### Evaluate ['FLAIR'] on fold 2: ###
# 100%|██████████| 373/373 [00:00<00:00, 376.30it/s]
# 100%|██████████| 373/373 [00:00<00:00, 392.45it/s]
# 100%|██████████| 93/93 [00:00<00:00, 350.21it/s]
#  Hold out:
# Val loss: 1.17777 - time: 0:00:05.395374
# Patient AUC: 0.57375 - Slice AUC: 0.52369
# ### Evaluate ['FLAIR'] on fold 3: ###
# 100%|██████████| 373/373 [00:01<00:00, 363.40it/s]
# 100%|██████████| 373/373 [00:00<00:00, 373.77it/s]
# 100%|██████████| 93/93 [00:00<00:00, 401.54it/s]
#  Hold out:
# Val loss: 1.02693 - time: 0:00:04.432219
# Patient AUC: 0.51994 - Slice AUC: 0.51313
# ### Evaluate ['FLAIR'] on fold 4: ###
# 100%|██████████| 373/373 [00:01<00:00, 363.93it/s]
# 100%|██████████| 373/373 [00:01<00:00, 350.38it/s]
# 100%|██████████| 93/93 [00:00<00:00, 416.24it/s]
#  Hold out:
# Val loss: 0.84087 - time: 0:00:04.763394
# Patient AUC: 0.53942 - Slice AUC: 0.51479
# ---
# ['FLAIR'] holdout result:
#  Mean AUC: 0.53337
#  Out-of-fold AUC: 0.52875
# ---

# %% [markdown]
# submission

# %%
test_results = []
for fold, weights_path in enumerate(weights_paths):
    print(f'### Inference {mri_types} on fold {fold}: ###')
    test_ds = pipeline.prepare_test_dataset(mri_types=mri_types, cache_rate=0.0)
    pipeline.load_model(weights_path)
    test_result = pipeline.predict(test_ds, batch_size=batch_size, verbose=True)
    test_results.append(test_result)
# Out:
# ### Inference ['FLAIR'] on fold 0: ###
# 100%|██████████| 585/585 [00:04<00:00, 123.11it/s]
# Elapsed time: 0:02:43.323466
# ### Inference ['FLAIR'] on fold 1: ###
# 100%|██████████| 585/585 [00:01<00:00, 446.32it/s]
# Elapsed time: 0:00:28.469974
# ### Inference ['FLAIR'] on fold 2: ###
# 100%|██████████| 585/585 [00:01<00:00, 445.30it/s]
# Elapsed time: 0:00:28.260193
# ### Inference ['FLAIR'] on fold 3: ###
# 100%|██████████| 585/585 [00:01<00:00, 448.59it/s]
# Elapsed time: 0:00:28.217544
# ### Inference ['FLAIR'] on fold 4: ###
# 100%|██████████| 585/585 [00:01<00:00, 450.16it/s]
# Elapsed time: 0:00:29.118069

# %%
prediction = pd.concat([x.set_index('BraTS21ID') for x in test_results], axis=1).mean(axis=1)
prediction = pd.DataFrame(prediction, columns=['MGMT_value']).reset_index()
# prediction.to_csv('submission_T1wCE.csv',index=False)

# %%
prediction
# Out:
#      BraTS21ID  MGMT_value
# 0            0    0.799002
# 1            2    0.857802
# 2            3    0.466467
# 3            5    0.803545
# 4            6    0.741668
# ..         ...         ...
# 580       1005    0.552404
# 581       1007    0.366012
# 582       1008    0.566009
# 583       1009    0.483141
# 584       1010    0.192406
#
# [585 rows x 2 columns]

# %%
test_df
# Out:
#      BraTS21ID  MGMT_value
# 0          107           1
# 1          753           0
# 2          303           1
# 3          106           1
# 4          171           1
# ..         ...         ...
# 112        703           0
# 113         21           0
# 114        444           0
# 115         95           0
# 116        640           1
#
# [117 rows x 2 columns]

# %%
result = pd.merge(prediction, test_df, on='BraTS21ID', how='right')

# %%
result
# Out:
#      BraTS21ID  MGMT_value_x  MGMT_value_y
# 0          107      0.417566             1
# 1          753      0.516087             0
# 2          303      0.292858             1
# 3          106      0.378623             1
# 4          171      0.472401             1
# ..         ...           ...           ...
# 112        703      0.652167             0
# 113         21      0.544203             0
# 114        444      0.484825             0
# 115         95      0.823517             0
# 116        640      0.649655             1
#
# [117 rows x 3 columns]

# %%
def get_confusion_matrix(result3, threshold=0.5):

    confusion_matrix = [[0, 0], [0, 0]]

#     for i in range(len(result3)):
#         threshold = 1 if result3.loc[i, "MGMT_value_x"] > threshold else 0
#         confusion_matrix[result3.loc[i, "MGMT_value_y"]][threshold] += 1
        
    for idx, data in result3.iterrows():
        tmp = 1 if data.MGMT_value_x > threshold else 0
        confusion_matrix[int(data.MGMT_value_y)][tmp] += 1

    return confusion_matrix

def get_acc_recall(arr):
    acc = sum((arr[0][0], arr[1][1]))/sum((sum(arr[0]), sum(arr[1])))
    recall = arr[1][1] / sum(arr[1])
    print(f"Acc: {acc} \t Recall: {recall}")

# %%
arr = get_confusion_matrix(result)
print(arr)
get_acc_recall(arr)
# Out:
# [[27, 29], [25, 36]]
# Acc: 0.5384615384615384 	 Recall: 0.5901639344262295
